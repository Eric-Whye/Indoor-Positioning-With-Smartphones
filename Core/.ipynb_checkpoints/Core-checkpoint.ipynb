# %%
import pandas as pd
import xml.etree.ElementTree as ET
import numpy as np
import math as math
import matplotlib.pyplot as plt

# %% [markdown]
# # Variables

# %%
lowerLimit = -70 #Lower limit of rssi acceptance values
limit_number = 2 #The accepted lower limit of rssi from matching mac addresses of the same coordinate as a result of multiple scans.
#i.e when averaging rssi, if the denominator is <= 1, remove it.

# %% [markdown]
# ## Grid Data

# %%
gridData = ET.parse("Grid-Data10.xml")

# %%
gridDataRoot = gridData.getroot()

# %%
class GridPoint:
    def __init__(self, X, Y, df=None):
        self.X = X
        self.Y = Y
        if df is None:
            df = None
        else:
            self.df = df
    def __str__(self):
        return f"{self.X}, {self.Y}. {self.df}"
    def __repr__(self):
        return self.__str__()

# %%
#Creates a list of grid points for every grid point received from data

gridPointsList = []
for grid in gridDataRoot:
    X = grid.find("X").text
    Y = grid.find("Y").text
    data = []

    for wifiPoint in grid.find("wifi"):
        if (int(wifiPoint.text) < lowerLimit):
            continue
        
        data.append({"mac_ad": wifiPoint.attrib.get("mac_ad"), 
             "rssi": int(wifiPoint.text), 
             "ssid": wifiPoint.attrib.get("ssid")})
    df = pd.DataFrame(data)
    gridPointsList.append(GridPoint(X, Y, df))
    
    
gridPointsList
# Out:
# [3.0, -3.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -52  UCD Wireless
#  1  a0:b4:39:33:29:e2   -59  UCD Wireless
#  2  a0:b4:39:33:29:e1   -59       eduroam
#  3  a0:b4:39:33:29:ee   -53       eduroam
#  4  3c:51:0e:ac:e9:01   -69       eduroam
#  5  3c:51:0e:ac:e9:02   -69  UCD Wireless,
#  3.0, -3.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -52  UCD Wireless
#  1  a0:b4:39:33:29:ee   -53       eduroam
#  2  3c:51:0e:ac:e9:01   -69       eduroam
#  3  3c:51:0e:ac:e9:02   -69  UCD Wireless,
#  3.0, -3.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -55  UCD Wireless
#  1  a0:b4:39:33:29:e2   -59  UCD Wireless
#  2  a0:b4:39:33:29:e1   -59       eduroam
#  3  a0:b4:39:33:29:ee   -53       eduroam,
#  3.0, -3.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -55  UCD Wireless
#  1  a0:b4:39:33:29:e2   -59  UCD Wireless
#  2  a0:b4:39:33:29:e1   -59       eduroam
#  3  a0:b4:39:33:29:ee   -53       eduroam,
#  3.0, -3.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -54  UCD Wireless
#  1  a0:b4:39:33:29:e2   -67  UCD Wireless
#  2  a0:b4:39:33:29:e1   -68       eduroam
#  3  a0:b4:39:33:29:ee   -55       eduroam
#  4  3c:51:0e:ac:e9:02   -70  UCD Wireless,
#  2.0, -3.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -53  UCD Wireless
#  1  a0:b4:39:33:29:e2   -64  UCD Wireless
#  2  a0:b4:39:33:29:e1   -64       eduroam
#  3  a0:b4:39:33:29:ee   -54       eduroam,
#  2.0, -3.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -53  UCD Wireless
#  1  a0:b4:39:33:29:e2   -64  UCD Wireless
#  2  a0:b4:39:33:29:e1   -64       eduroam
#  3  a0:b4:39:33:29:ee   -54       eduroam,
#  2.0, -3.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -52  UCD Wireless
#  1  a0:b4:39:33:29:e2   -58  UCD Wireless
#  2  a0:b4:39:33:29:e1   -58       eduroam
#  3  a0:b4:39:33:29:ee   -52       eduroam
#  4  3c:51:0e:ac:e9:01   -68       eduroam
#  5  3c:51:0e:ac:e9:02   -68  UCD Wireless,
#  2.0, -3.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -52  UCD Wireless
#  1  a0:b4:39:33:29:e2   -58  UCD Wireless
#  2  a0:b4:39:33:29:e1   -58       eduroam
#  3  a0:b4:39:33:29:ee   -52       eduroam
#  4  3c:51:0e:ac:e9:01   -68       eduroam
#  5  3c:51:0e:ac:e9:02   -68  UCD Wireless,
#  2.0, -3.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -58  UCD Wireless
#  1  a0:b4:39:33:29:e2   -55  UCD Wireless
#  2  a0:b4:39:33:29:e1   -55       eduroam
#  3  a0:b4:39:33:29:ee   -57       eduroam
#  4  3c:51:0e:ac:e9:0e   -70       eduroam
#  5  3c:51:0e:ac:e9:0d   -69  UCD Wireless,
#  2.0, -3.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -58  UCD Wireless
#  1  a0:b4:39:33:29:e1   -55       eduroam
#  2  a0:b4:39:33:29:ee   -57       eduroam
#  3  3c:51:0e:ac:e9:0e   -70       eduroam
#  4  3c:51:0e:ac:e9:0d   -69  UCD Wireless,
#  1.0, -3.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -52  UCD Wireless
#  1  a0:b4:39:33:29:e2   -61  UCD Wireless
#  2  a0:b4:39:33:29:e1   -61       eduroam
#  3  a0:b4:39:33:29:ee   -52       eduroam
#  4  3c:51:0e:ac:e9:0e   -70       eduroam
#  5  3c:51:0e:ac:e9:0d   -70  UCD Wireless,
#  1.0, -3.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -52  UCD Wireless
#  1  a0:b4:39:33:29:e2   -61  UCD Wireless
#  2  a0:b4:39:33:29:e1   -61       eduroam
#  3  a0:b4:39:33:29:ee   -52       eduroam
#  4  3c:51:0e:ac:e9:0e   -70       eduroam
#  5  3c:51:0e:ac:e9:0d   -70  UCD Wireless,
#  1.0, -3.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -53  UCD Wireless
#  1  a0:b4:39:33:29:e2   -69  UCD Wireless
#  2  a0:b4:39:33:29:e1   -68       eduroam
#  3  a0:b4:39:33:29:ee   -53       eduroam,
#  1.0, -3.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -53  UCD Wireless
#  1  a0:b4:39:33:29:e2   -69  UCD Wireless
#  2  a0:b4:39:33:29:e1   -68       eduroam
#  3  a0:b4:39:33:29:ee   -53       eduroam,
#  1.0, -3.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -51  UCD Wireless
#  1  a0:b4:39:33:29:e2   -61  UCD Wireless
#  2  a0:b4:39:33:29:e1   -61       eduroam
#  3  a0:b4:39:33:29:ee   -55       eduroam
#  4  3c:51:0e:ac:e9:0e   -69       eduroam
#  5  3c:51:0e:ac:e9:0d   -69  UCD Wireless,
#  0.0, -3.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -51  UCD Wireless
#  1  a0:b4:39:33:29:e2   -61  UCD Wireless
#  2  a0:b4:39:33:29:e1   -61       eduroam
#  3  a0:b4:39:33:29:ee   -55       eduroam
#  4  3c:51:0e:ac:e9:0e   -69       eduroam
#  5  3c:51:0e:ac:e9:0d   -69  UCD Wireless,
#  0.0, -3.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -57  UCD Wireless
#  1  a0:b4:39:33:29:e2   -64  UCD Wireless
#  2  a0:b4:39:33:29:e1   -64       eduroam
#  3  a0:b4:39:33:29:ee   -56       eduroam
#  4  3c:51:0e:ac:e9:0e   -64       eduroam
#  5  3c:51:0e:ac:e9:0d   -64  UCD Wireless,
#  0.0, -3.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -57  UCD Wireless
#  1  a0:b4:39:33:29:ee   -56       eduroam
#  2  3c:51:0e:ac:e9:0e   -64       eduroam
#  3  3c:51:0e:ac:e9:0d   -64  UCD Wireless,
#  -1.0, -3.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -52  UCD Wireless
#  1  a0:b4:39:33:29:e2   -59  UCD Wireless
#  2  a0:b4:39:33:29:e1   -59       eduroam
#  3  a0:b4:39:33:29:ee   -52       eduroam
#  4  3c:51:0e:ac:e9:0e   -65       eduroam
#  5  3c:51:0e:ac:e9:0d   -65  UCD Wireless,
#  -1.0, -3.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -52  UCD Wireless
#  1  a0:b4:39:33:29:e2   -59  UCD Wireless
#  2  a0:b4:39:33:29:e1   -59       eduroam
#  3  a0:b4:39:33:29:ee   -52       eduroam
#  4  3c:51:0e:ac:e9:0e   -65       eduroam
#  5  3c:51:0e:ac:e9:0d   -65  UCD Wireless,
#  -1.0, -3.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -48  UCD Wireless
#  1  a0:b4:39:33:29:e2   -65  UCD Wireless
#  2  a0:b4:39:33:29:e1   -65       eduroam
#  3  a0:b4:39:33:29:ee   -49       eduroam
#  4  3c:51:0e:ac:e9:0e   -69       eduroam
#  5  3c:51:0e:ac:e9:0d   -68  UCD Wireless,
#  -1.0, -3.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -48  UCD Wireless
#  1  a0:b4:39:33:29:e2   -65  UCD Wireless
#  2  a0:b4:39:33:29:e1   -65       eduroam
#  3  a0:b4:39:33:29:ee   -49       eduroam
#  4  3c:51:0e:ac:e9:0e   -69       eduroam
#  5  3c:51:0e:ac:e9:0d   -68  UCD Wireless,
#  -2.0, -3.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -48  UCD Wireless
#  1  a0:b4:39:33:29:e2   -57  UCD Wireless
#  2  a0:b4:39:33:29:e1   -56       eduroam
#  3  a0:b4:39:33:29:ee   -52       eduroam
#  4  3c:51:0e:ac:e9:01   -67       eduroam
#  5  3c:51:0e:ac:e9:02   -67  UCD Wireless,
#  -2.0, -3.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -48  UCD Wireless
#  1  a0:b4:39:33:29:e2   -57  UCD Wireless
#  2  a0:b4:39:33:29:e1   -56       eduroam
#  3  a0:b4:39:33:29:ee   -52       eduroam
#  4  3c:51:0e:ac:e9:01   -67       eduroam
#  5  3c:51:0e:ac:e9:02   -67  UCD Wireless,
#  -2.0, -3.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -56  UCD Wireless
#  1  a0:b4:39:33:29:e2   -63  UCD Wireless
#  2  a0:b4:39:33:29:e1   -61       eduroam
#  3  a0:b4:39:33:29:ee   -58       eduroam
#  4  3c:51:0e:ac:e9:0d   -70  UCD Wireless
#  5  3c:51:0e:ac:e9:01   -70       eduroam
#  6  3c:51:0e:ac:e9:02   -70  UCD Wireless,
#  -2.0, -3.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -56  UCD Wireless
#  1  a0:b4:39:33:29:e2   -63  UCD Wireless
#  2  a0:b4:39:33:29:e1   -61       eduroam
#  3  a0:b4:39:33:29:ee   -58       eduroam
#  4  3c:51:0e:ac:e9:0d   -70  UCD Wireless
#  5  3c:51:0e:ac:e9:01   -70       eduroam
#  6  3c:51:0e:ac:e9:02   -70  UCD Wireless,
#  -3.0, -3.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -58  UCD Wireless
#  1  a0:b4:39:33:29:e2   -60  UCD Wireless
#  2  a0:b4:39:33:29:e1   -59       eduroam
#  3  a0:b4:39:33:29:ee   -60       eduroam
#  4  3c:51:0e:ac:e9:0e   -70       eduroam
#  5  3c:51:0e:ac:e9:0d   -69  UCD Wireless
#  6  3c:51:0e:ac:e9:01   -70       eduroam
#  7  3c:51:0e:ac:e9:02   -70  UCD Wireless,
#  -3.0, -3.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -58  UCD Wireless
#  1  a0:b4:39:33:29:e2   -60  UCD Wireless
#  2  a0:b4:39:33:29:e1   -59       eduroam
#  3  a0:b4:39:33:29:ee   -60       eduroam
#  4  3c:51:0e:ac:e9:0e   -70       eduroam
#  5  3c:51:0e:ac:e9:0d   -69  UCD Wireless
#  6  3c:51:0e:ac:e9:01   -70       eduroam
#  7  3c:51:0e:ac:e9:02   -70  UCD Wireless,
#  -3.0, -3.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -54  UCD Wireless
#  1  a0:b4:39:33:29:e2   -58  UCD Wireless
#  2  a0:b4:39:33:29:e1   -58       eduroam
#  3  a0:b4:39:33:29:ee   -57       eduroam
#  4  3c:51:0e:ac:e9:0e   -69       eduroam
#  5  3c:51:0e:ac:e9:0d   -69  UCD Wireless
#  6  a0:b4:39:54:ad:6d   -70  UCD Wireless
#  7  a0:b4:39:54:ad:6e   -70       eduroam
#  8  3c:51:0e:ac:e9:01   -70       eduroam
#  9  3c:51:0e:ac:e9:02   -70  UCD Wireless,
#  -3.0, -3.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -54  UCD Wireless
#  1  a0:b4:39:33:29:e2   -58  UCD Wireless
#  2  a0:b4:39:33:29:e1   -58       eduroam
#  3  a0:b4:39:33:29:ee   -57       eduroam
#  4  3c:51:0e:ac:e9:0e   -69       eduroam
#  5  3c:51:0e:ac:e9:0d   -69  UCD Wireless
#  6  a0:b4:39:54:ad:6d   -70  UCD Wireless
#  7  a0:b4:39:54:ad:6e   -70       eduroam
#  8  3c:51:0e:ac:e9:01   -70       eduroam
#  9  3c:51:0e:ac:e9:02   -70  UCD Wireless,
#  -3.0, -2.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -50  UCD Wireless
#  1  a0:b4:39:33:29:e2   -63  UCD Wireless
#  2  a0:b4:39:33:29:e1   -66       eduroam
#  3  a0:b4:39:33:29:ee   -54       eduroam
#  4  3c:51:0e:ac:e9:0e   -69       eduroam
#  5  3c:51:0e:ac:e9:0d   -68  UCD Wireless,
#  -3.0, -2.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -50  UCD Wireless
#  1  a0:b4:39:33:29:e2   -63  UCD Wireless
#  2  a0:b4:39:33:29:e1   -66       eduroam
#  3  a0:b4:39:33:29:ee   -54       eduroam
#  4  3c:51:0e:ac:e9:0e   -69       eduroam
#  5  3c:51:0e:ac:e9:0d   -68  UCD Wireless,
#  -3.0, -2.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -50  UCD Wireless
#  1  a0:b4:39:33:29:e2   -57  UCD Wireless
#  2  a0:b4:39:33:29:e1   -56       eduroam
#  3  a0:b4:39:33:29:ee   -52       eduroam
#  4  3c:51:0e:ac:e9:0e   -64       eduroam
#  5  3c:51:0e:ac:e9:0d   -65  UCD Wireless,
#  -3.0, -2.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -50  UCD Wireless
#  1  a0:b4:39:33:29:e2   -57  UCD Wireless
#  2  a0:b4:39:33:29:e1   -56       eduroam
#  3  a0:b4:39:33:29:ee   -52       eduroam
#  4  3c:51:0e:ac:e9:0e   -64       eduroam
#  5  3c:51:0e:ac:e9:0d   -65  UCD Wireless,
#  -3.0, -2.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -49  UCD Wireless
#  1  a0:b4:39:33:29:e2   -56  UCD Wireless
#  2  a0:b4:39:33:29:e1   -57       eduroam
#  3  a0:b4:39:33:29:ee   -51       eduroam
#  4  3c:51:0e:ac:e9:0e   -67       eduroam
#  5  3c:51:0e:ac:e9:0d   -67  UCD Wireless
#  6  3c:51:0e:ac:e9:01   -67       eduroam
#  7  3c:51:0e:ac:e9:02   -68  UCD Wireless
#  8  a0:b4:39:28:2c:ce   -70       eduroam
#  9  a0:b4:39:28:2c:cd   -70  UCD Wireless,
#  -2.0, -2.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -54  UCD Wireless
#  1  a0:b4:39:33:29:e2   -57  UCD Wireless
#  2  a0:b4:39:33:29:e1   -57       eduroam
#  3  a0:b4:39:33:29:ee   -51       eduroam
#  4  3c:51:0e:ac:e9:0e   -69       eduroam
#  5  3c:51:0e:ac:e9:0d   -69  UCD Wireless
#  6  3c:51:0e:ac:e9:01   -67       eduroam
#  7  3c:51:0e:ac:e9:02   -67  UCD Wireless,
#  -2.0, -2.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -54  UCD Wireless
#  1  a0:b4:39:33:29:e2   -57  UCD Wireless
#  2  a0:b4:39:33:29:e1   -57       eduroam
#  3  a0:b4:39:33:29:ee   -51       eduroam
#  4  3c:51:0e:ac:e9:0e   -69       eduroam
#  5  3c:51:0e:ac:e9:0d   -69  UCD Wireless
#  6  3c:51:0e:ac:e9:01   -67       eduroam
#  7  3c:51:0e:ac:e9:02   -67  UCD Wireless,
#  -2.0, -2.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -57  UCD Wireless
#  1  a0:b4:39:33:29:e2   -64  UCD Wireless
#  2  a0:b4:39:33:29:e1   -64       eduroam
#  3  a0:b4:39:33:29:ee   -56       eduroam,
#  -2.0, -2.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -57  UCD Wireless
#  1  a0:b4:39:33:29:e2   -64  UCD Wireless
#  2  a0:b4:39:33:29:e1   -64       eduroam
#  3  a0:b4:39:33:29:ee   -56       eduroam,
#  -2.0, -2.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -54  UCD Wireless
#  1  a0:b4:39:33:29:e2   -55  UCD Wireless
#  2  a0:b4:39:33:29:e1   -55       eduroam
#  3  a0:b4:39:33:29:ee   -53       eduroam
#  4  3c:51:0e:ac:e9:0e   -68       eduroam
#  5  3c:51:0e:ac:e9:0d   -68  UCD Wireless
#  6  3c:51:0e:ac:e9:01   -62       eduroam
#  7  3c:51:0e:ac:e9:02   -62  UCD Wireless,
#  -1.0, -2.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -53  UCD Wireless
#  1  a0:b4:39:33:29:e2   -57  UCD Wireless
#  2  a0:b4:39:33:29:e1   -56       eduroam
#  3  a0:b4:39:33:29:ee   -54       eduroam
#  4  3c:51:0e:ac:e9:0e   -70       eduroam
#  5  3c:51:0e:ac:e9:0d   -70  UCD Wireless
#  6  3c:51:0e:ac:e9:01   -65       eduroam
#  7  3c:51:0e:ac:e9:02   -65  UCD Wireless,
#  -1.0, -2.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -53  UCD Wireless
#  1  a0:b4:39:33:29:e2   -57  UCD Wireless
#  2  a0:b4:39:33:29:e1   -56       eduroam
#  3  a0:b4:39:33:29:ee   -54       eduroam
#  4  3c:51:0e:ac:e9:0e   -70       eduroam
#  5  3c:51:0e:ac:e9:0d   -70  UCD Wireless
#  6  3c:51:0e:ac:e9:01   -65       eduroam
#  7  3c:51:0e:ac:e9:02   -65  UCD Wireless,
#  -1.0, -2.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -52  UCD Wireless
#  1  a0:b4:39:33:29:e2   -59  UCD Wireless
#  2  a0:b4:39:33:29:e1   -59       eduroam
#  3  a0:b4:39:33:29:ee   -51       eduroam
#  4  3c:51:0e:ac:e9:01   -69       eduroam
#  5  3c:51:0e:ac:e9:02   -69  UCD Wireless,
#  -1.0, -2.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -52  UCD Wireless
#  1  a0:b4:39:33:29:e2   -59  UCD Wireless
#  2  a0:b4:39:33:29:e1   -59       eduroam
#  3  a0:b4:39:33:29:ee   -51       eduroam
#  4  3c:51:0e:ac:e9:01   -69       eduroam
#  5  3c:51:0e:ac:e9:02   -69  UCD Wireless,
#  0.0, -2.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -50  UCD Wireless
#  1  a0:b4:39:33:29:e2   -65  UCD Wireless
#  2  a0:b4:39:33:29:e1   -65       eduroam
#  3  a0:b4:39:33:29:ee   -52       eduroam,
#  0.0, -2.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -50  UCD Wireless
#  1  a0:b4:39:33:29:e2   -65  UCD Wireless
#  2  a0:b4:39:33:29:e1   -65       eduroam
#  3  a0:b4:39:33:29:ee   -52       eduroam,
#  0.0, -2.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -50  UCD Wireless
#  1  a0:b4:39:33:29:e2   -66  UCD Wireless
#  2  a0:b4:39:33:29:e1   -65       eduroam
#  3  a0:b4:39:33:29:ee   -50       eduroam
#  4  3c:51:0e:ac:e9:0e   -67       eduroam
#  5  3c:51:0e:ac:e9:0d   -67  UCD Wireless,
#  0.0, -2.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -50  UCD Wireless
#  1  a0:b4:39:33:29:e2   -66  UCD Wireless
#  2  a0:b4:39:33:29:e1   -65       eduroam
#  3  a0:b4:39:33:29:ee   -50       eduroam
#  4  3c:51:0e:ac:e9:0e   -67       eduroam
#  5  3c:51:0e:ac:e9:0d   -67  UCD Wireless,
#  1.0, -2.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -51  UCD Wireless
#  1  a0:b4:39:33:29:e2   -62  UCD Wireless
#  2  a0:b4:39:33:29:e1   -62       eduroam
#  3  a0:b4:39:33:29:ee   -53       eduroam
#  4  3c:51:0e:ac:e9:0e   -69       eduroam
#  5  3c:51:0e:ac:e9:0d   -68  UCD Wireless,
#  1.0, -2.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -51  UCD Wireless
#  1  a0:b4:39:33:29:e2   -62  UCD Wireless
#  2  a0:b4:39:33:29:e1   -62       eduroam
#  3  a0:b4:39:33:29:ee   -53       eduroam
#  4  3c:51:0e:ac:e9:0e   -69       eduroam
#  5  3c:51:0e:ac:e9:0d   -68  UCD Wireless,
#  1.0, -2.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -53  UCD Wireless
#  1  a0:b4:39:33:29:e2   -60  UCD Wireless
#  2  a0:b4:39:33:29:e1   -59       eduroam
#  3  a0:b4:39:33:29:ee   -55       eduroam
#  4  3c:51:0e:ac:e9:02   -69  UCD Wireless,
#  2.0, -2.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -57  UCD Wireless
#  1  a0:b4:39:33:29:e2   -64  UCD Wireless
#  2  a0:b4:39:33:29:e1   -64       eduroam
#  3  a0:b4:39:33:29:ee   -59       eduroam,
#  2.0, -2.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -57  UCD Wireless
#  1  a0:b4:39:33:29:e2   -64  UCD Wireless
#  2  a0:b4:39:33:29:e1   -64       eduroam
#  3  a0:b4:39:33:29:ee   -59       eduroam,
#  2.0, -2.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -53  UCD Wireless
#  1  a0:b4:39:33:29:e2   -62  UCD Wireless
#  2  a0:b4:39:33:29:e1   -62       eduroam
#  3  a0:b4:39:33:29:ee   -54       eduroam
#  4  3c:51:0e:ac:e9:0e   -66       eduroam
#  5  3c:51:0e:ac:e9:0d   -66  UCD Wireless
#  6  3c:51:0e:ac:e9:01   -68       eduroam
#  7  3c:51:0e:ac:e9:02   -68  UCD Wireless,
#  3.0, -2.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -53  UCD Wireless
#  1  a0:b4:39:33:29:e2   -59  UCD Wireless
#  2  a0:b4:39:33:29:e1   -60       eduroam
#  3  a0:b4:39:33:29:ee   -55       eduroam
#  4  3c:51:0e:ac:e9:0e   -69       eduroam
#  5  3c:51:0e:ac:e9:0d   -69  UCD Wireless,
#  3.0, -2.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -53  UCD Wireless
#  1  a0:b4:39:33:29:e2   -59  UCD Wireless
#  2  a0:b4:39:33:29:e1   -60       eduroam
#  3  a0:b4:39:33:29:ee   -55       eduroam
#  4  3c:51:0e:ac:e9:0e   -69       eduroam
#  5  3c:51:0e:ac:e9:0d   -69  UCD Wireless,
#  3.0, -2.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -58  UCD Wireless
#  1  a0:b4:39:33:29:e2   -60  UCD Wireless
#  2  a0:b4:39:33:29:e1   -63       eduroam
#  3  a0:b4:39:33:29:ee   -55       eduroam,
#  3.0, -2.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -58  UCD Wireless
#  1  a0:b4:39:33:29:e2   -60  UCD Wireless
#  2  a0:b4:39:33:29:e1   -63       eduroam
#  3  a0:b4:39:33:29:ee   -55       eduroam,
#  3.0, -1.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -57  UCD Wireless
#  1  a0:b4:39:33:29:e2   -65  UCD Wireless
#  2  a0:b4:39:33:29:e1   -65       eduroam
#  3  a0:b4:39:33:29:ee   -56       eduroam
#  4  3c:51:0e:ac:e9:01   -70       eduroam
#  5  3c:51:0e:ac:e9:02   -70  UCD Wireless,
#  3.0, -1.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -57  UCD Wireless
#  1  a0:b4:39:33:29:e1   -65       eduroam
#  2  a0:b4:39:33:29:ee   -56       eduroam
#  3  3c:51:0e:ac:e9:01   -70       eduroam
#  4  3c:51:0e:ac:e9:02   -70  UCD Wireless,
#  3.0, -1.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -51  UCD Wireless
#  1  a0:b4:39:33:29:e2   -68  UCD Wireless
#  2  a0:b4:39:33:29:e1   -68       eduroam
#  3  a0:b4:39:33:29:ee   -57       eduroam,
#  2.0, -1.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -51  UCD Wireless
#  1  a0:b4:39:33:29:e2   -68  UCD Wireless
#  2  a0:b4:39:33:29:e1   -68       eduroam
#  3  a0:b4:39:33:29:ee   -57       eduroam,
#  2.0, -1.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -59  UCD Wireless
#  1  a0:b4:39:37:31:02   -69  UCD Wireless
#  2  a0:b4:39:37:31:01   -69       eduroam
#  3  a0:b4:39:33:29:e2   -64  UCD Wireless
#  4  a0:b4:39:33:29:e1   -64       eduroam
#  5  a0:b4:39:33:29:ee   -53       eduroam
#  6  a0:b4:39:54:ad:6d   -70  UCD Wireless
#  7  a0:b4:39:54:ad:6e   -70       eduroam,
#  2.0, -1.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -59  UCD Wireless
#  1  a0:b4:39:37:31:02   -69  UCD Wireless
#  2  a0:b4:39:37:31:01   -69       eduroam
#  3  a0:b4:39:33:29:e2   -64  UCD Wireless
#  4  a0:b4:39:33:29:e1   -64       eduroam
#  5  a0:b4:39:33:29:ee   -53       eduroam
#  6  a0:b4:39:54:ad:6d   -70  UCD Wireless
#  7  a0:b4:39:54:ad:6e   -70       eduroam,
#  2.0, -1.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -51  UCD Wireless
#  1  a0:b4:39:37:31:02   -70  UCD Wireless
#  2  a0:b4:39:37:31:01   -70       eduroam
#  3  a0:b4:39:33:29:e2   -61  UCD Wireless
#  4  a0:b4:39:33:29:e1   -61       eduroam
#  5  a0:b4:39:33:29:ee   -56       eduroam,
#  1.0, -1.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -51  UCD Wireless
#  1  a0:b4:39:37:31:02   -70  UCD Wireless
#  2  a0:b4:39:37:31:01   -70       eduroam
#  3  a0:b4:39:33:29:e2   -61  UCD Wireless
#  4  a0:b4:39:33:29:e1   -61       eduroam
#  5  a0:b4:39:33:29:ee   -56       eduroam,
#  1.0, -1.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -58  UCD Wireless
#  1  a0:b4:39:37:31:02   -68  UCD Wireless
#  2  a0:b4:39:37:31:01   -66       eduroam
#  3  a0:b4:39:33:29:e2   -64  UCD Wireless
#  4  a0:b4:39:33:29:e1   -65       eduroam
#  5  a0:b4:39:33:29:ee   -58       eduroam
#  6  3c:51:0e:ac:e9:01   -70       eduroam
#  7  3c:51:0e:ac:e9:02   -70  UCD Wireless,
#  1.0, -1.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -58  UCD Wireless
#  1  a0:b4:39:37:31:02   -68  UCD Wireless
#  2  a0:b4:39:37:31:01   -66       eduroam
#  3  a0:b4:39:33:29:e2   -64  UCD Wireless
#  4  a0:b4:39:33:29:e1   -65       eduroam
#  5  a0:b4:39:33:29:ee   -58       eduroam
#  6  3c:51:0e:ac:e9:01   -70       eduroam
#  7  3c:51:0e:ac:e9:02   -70  UCD Wireless,
#  1.0, -1.0.                mac_ad  rssi          ssid
#  0   a0:b4:39:33:29:ed   -53  UCD Wireless
#  1   a0:b4:39:37:31:02   -70  UCD Wireless
#  2   a0:b4:39:37:31:01   -70       eduroam
#  3   a0:b4:39:33:29:e2   -64  UCD Wireless
#  4   a0:b4:39:33:29:e1   -64       eduroam
#  5   a0:b4:39:33:29:ee   -53       eduroam
#  6   3c:51:0e:ac:e9:0e   -68       eduroam
#  7   a0:b4:39:54:ad:6d   -68  UCD Wireless
#  8   3c:51:0e:ac:e9:0d   -68  UCD Wireless
#  9   a0:b4:39:54:ad:6e   -67       eduroam
#  10  3c:51:0e:ac:e9:01   -66       eduroam
#  11  3c:51:0e:ac:e9:02   -66  UCD Wireless,
#  0.0, -1.0.                mac_ad  rssi          ssid
#  0   a0:b4:39:33:29:ed   -53  UCD Wireless
#  1   a0:b4:39:37:31:02   -70  UCD Wireless
#  2   a0:b4:39:37:31:01   -70       eduroam
#  3   a0:b4:39:33:29:e2   -64  UCD Wireless
#  4   a0:b4:39:33:29:e1   -64       eduroam
#  5   a0:b4:39:33:29:ee   -53       eduroam
#  6   3c:51:0e:ac:e9:0e   -68       eduroam
#  7   a0:b4:39:54:ad:6d   -68  UCD Wireless
#  8   3c:51:0e:ac:e9:0d   -68  UCD Wireless
#  9   a0:b4:39:54:ad:6e   -67       eduroam
#  10  3c:51:0e:ac:e9:01   -66       eduroam
#  11  3c:51:0e:ac:e9:02   -66  UCD Wireless,
#  0.0, -1.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -55  UCD Wireless
#  1  a0:b4:39:33:29:e2   -60  UCD Wireless
#  2  a0:b4:39:33:29:e1   -63       eduroam
#  3  a0:b4:39:33:29:ee   -52       eduroam
#  4  3c:51:0e:ac:e9:0e   -68       eduroam
#  5  3c:51:0e:ac:e9:0d   -68  UCD Wireless
#  6  3c:51:0e:ac:e9:01   -69       eduroam
#  7  3c:51:0e:ac:e9:02   -69  UCD Wireless,
#  0.0, -1.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -55  UCD Wireless
#  1  a0:b4:39:33:29:e2   -60  UCD Wireless
#  2  a0:b4:39:33:29:e1   -63       eduroam
#  3  a0:b4:39:33:29:ee   -52       eduroam
#  4  3c:51:0e:ac:e9:0e   -68       eduroam
#  5  3c:51:0e:ac:e9:0d   -68  UCD Wireless
#  6  3c:51:0e:ac:e9:01   -69       eduroam
#  7  3c:51:0e:ac:e9:02   -69  UCD Wireless,
#  0.0, -1.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -53  UCD Wireless
#  1  a0:b4:39:33:29:e2   -59  UCD Wireless
#  2  a0:b4:39:33:29:e1   -58       eduroam
#  3  a0:b4:39:33:29:ee   -50       eduroam
#  4  3c:51:0e:ac:e9:02   -69  UCD Wireless,
#  -1.0, -1.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -56  UCD Wireless
#  1  a0:b4:39:33:29:e2   -56  UCD Wireless
#  2  a0:b4:39:33:29:e1   -56       eduroam
#  3  a0:b4:39:33:29:ee   -55       eduroam
#  4  3c:51:0e:ac:e9:0e   -68       eduroam
#  5  3c:51:0e:ac:e9:0d   -68  UCD Wireless
#  6  a0:b4:39:54:ad:6d   -69  UCD Wireless
#  7  a0:b4:39:54:ad:6e   -69       eduroam
#  8  3c:51:0e:ac:e9:02   -68  UCD Wireless,
#  -1.0, -1.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -56  UCD Wireless
#  1  a0:b4:39:33:29:e2   -56  UCD Wireless
#  2  a0:b4:39:33:29:e1   -56       eduroam
#  3  a0:b4:39:33:29:ee   -55       eduroam
#  4  3c:51:0e:ac:e9:0e   -68       eduroam
#  5  3c:51:0e:ac:e9:0d   -68  UCD Wireless
#  6  a0:b4:39:54:ad:6d   -69  UCD Wireless
#  7  a0:b4:39:54:ad:6e   -69       eduroam
#  8  3c:51:0e:ac:e9:02   -68  UCD Wireless,
#  -1.0, -1.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -60  UCD Wireless
#  1  a0:b4:39:33:29:e2   -65  UCD Wireless
#  2  a0:b4:39:33:29:e1   -65       eduroam
#  3  a0:b4:39:33:29:ee   -58       eduroam
#  4  a0:b4:39:54:ad:6d   -69  UCD Wireless
#  5  a0:b4:39:54:ad:6e   -68       eduroam,
#  -2.0, -1.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -60  UCD Wireless
#  1  a0:b4:39:33:29:e2   -65  UCD Wireless
#  2  a0:b4:39:33:29:e1   -65       eduroam
#  3  a0:b4:39:33:29:ee   -58       eduroam
#  4  a0:b4:39:54:ad:6d   -69  UCD Wireless
#  5  a0:b4:39:54:ad:6e   -68       eduroam,
#  -2.0, -1.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -53  UCD Wireless
#  1  a0:b4:39:33:29:e2   -59  UCD Wireless
#  2  a0:b4:39:33:29:e1   -60       eduroam
#  3  a0:b4:39:33:29:ee   -54       eduroam
#  4  3c:51:0e:ac:e9:0e   -68       eduroam
#  5  a0:b4:39:54:ad:6d   -67  UCD Wireless
#  6  3c:51:0e:ac:e9:0d   -68  UCD Wireless
#  7  a0:b4:39:54:ad:6e   -67       eduroam
#  8  3c:51:0e:ac:e9:01   -62       eduroam
#  9  3c:51:0e:ac:e9:02   -62  UCD Wireless,
#  -2.0, -1.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -53  UCD Wireless
#  1  a0:b4:39:33:29:e2   -59  UCD Wireless
#  2  a0:b4:39:33:29:e1   -60       eduroam
#  3  a0:b4:39:33:29:ee   -54       eduroam
#  4  3c:51:0e:ac:e9:0e   -68       eduroam
#  5  a0:b4:39:54:ad:6d   -67  UCD Wireless
#  6  3c:51:0e:ac:e9:0d   -68  UCD Wireless
#  7  a0:b4:39:54:ad:6e   -67       eduroam
#  8  3c:51:0e:ac:e9:01   -62       eduroam
#  9  3c:51:0e:ac:e9:02   -62  UCD Wireless,
#  -2.0, -1.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -51  UCD Wireless
#  1  a0:b4:39:33:29:e2   -61  UCD Wireless
#  2  a0:b4:39:33:29:e1   -66       eduroam
#  3  a0:b4:39:33:29:ee   -52       eduroam
#  4  3c:51:0e:ac:e9:0e   -68       eduroam
#  5  3c:51:0e:ac:e9:0d   -67  UCD Wireless
#  6  a0:b4:39:54:ad:6d   -68  UCD Wireless
#  7  a0:b4:39:54:ad:6e   -67       eduroam
#  8  3c:51:0e:ac:e9:01   -65       eduroam
#  9  3c:51:0e:ac:e9:02   -65  UCD Wireless,
#  -3.0, -1.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -51  UCD Wireless
#  1  a0:b4:39:33:29:e2   -61  UCD Wireless
#  2  a0:b4:39:33:29:e1   -66       eduroam
#  3  a0:b4:39:33:29:ee   -52       eduroam
#  4  3c:51:0e:ac:e9:0e   -68       eduroam
#  5  3c:51:0e:ac:e9:0d   -67  UCD Wireless
#  6  a0:b4:39:54:ad:6d   -68  UCD Wireless
#  7  a0:b4:39:54:ad:6e   -67       eduroam
#  8  3c:51:0e:ac:e9:01   -65       eduroam
#  9  3c:51:0e:ac:e9:02   -65  UCD Wireless,
#  -3.0, -1.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -51  UCD Wireless
#  1  a0:b4:39:33:29:e2   -61  UCD Wireless
#  2  a0:b4:39:33:29:e1   -66       eduroam
#  3  a0:b4:39:33:29:ee   -52       eduroam
#  4  3c:51:0e:ac:e9:0e   -68       eduroam
#  5  3c:51:0e:ac:e9:0d   -67  UCD Wireless
#  6  a0:b4:39:54:ad:6d   -68  UCD Wireless
#  7  a0:b4:39:54:ad:6e   -67       eduroam
#  8  3c:51:0e:ac:e9:01   -65       eduroam
#  9  3c:51:0e:ac:e9:02   -65  UCD Wireless,
#  -3.0, -1.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -55  UCD Wireless
#  1  a0:b4:39:33:29:e2   -60  UCD Wireless
#  2  a0:b4:39:33:29:e1   -60       eduroam
#  3  a0:b4:39:33:29:ee   -52       eduroam
#  4  3c:51:0e:ac:e9:0e   -64       eduroam
#  5  3c:51:0e:ac:e9:0d   -63  UCD Wireless
#  6  a0:b4:39:54:ad:6d   -69  UCD Wireless
#  7  a0:b4:39:54:ad:6e   -69       eduroam
#  8  3c:51:0e:ac:e9:01   -62       eduroam
#  9  3c:51:0e:ac:e9:02   -62  UCD Wireless,
#  -3.0, -1.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -55  UCD Wireless
#  1  a0:b4:39:33:29:e2   -60  UCD Wireless
#  2  a0:b4:39:33:29:e1   -60       eduroam
#  3  a0:b4:39:33:29:ee   -52       eduroam
#  4  3c:51:0e:ac:e9:0e   -64       eduroam
#  5  3c:51:0e:ac:e9:0d   -63  UCD Wireless
#  6  a0:b4:39:54:ad:6d   -69  UCD Wireless
#  7  a0:b4:39:54:ad:6e   -69       eduroam
#  8  3c:51:0e:ac:e9:01   -62       eduroam
#  9  3c:51:0e:ac:e9:02   -62  UCD Wireless,
#  -3.0, -1.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -55  UCD Wireless
#  1  a0:b4:39:33:29:e2   -60  UCD Wireless
#  2  a0:b4:39:33:29:e1   -60       eduroam
#  3  a0:b4:39:33:29:ee   -52       eduroam
#  4  3c:51:0e:ac:e9:0e   -64       eduroam
#  5  3c:51:0e:ac:e9:0d   -63  UCD Wireless
#  6  a0:b4:39:54:ad:6d   -69  UCD Wireless
#  7  a0:b4:39:54:ad:6e   -69       eduroam
#  8  3c:51:0e:ac:e9:01   -62       eduroam
#  9  3c:51:0e:ac:e9:02   -62  UCD Wireless,
#  -3.0, -1.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -55  UCD Wireless
#  1  a0:b4:39:33:29:e2   -60  UCD Wireless
#  2  a0:b4:39:33:29:e1   -60       eduroam
#  3  a0:b4:39:33:29:ee   -52       eduroam
#  4  3c:51:0e:ac:e9:0e   -64       eduroam
#  5  3c:51:0e:ac:e9:0d   -63  UCD Wireless
#  6  a0:b4:39:54:ad:6d   -69  UCD Wireless
#  7  a0:b4:39:54:ad:6e   -69       eduroam
#  8  3c:51:0e:ac:e9:01   -62       eduroam
#  9  3c:51:0e:ac:e9:02   -62  UCD Wireless,
#  -3.0, 0.0.                mac_ad  rssi          ssid
#  0   a0:b4:39:33:29:ed   -44  UCD Wireless
#  1   a0:b4:39:54:ad:61   -65       eduroam
#  2   a0:b4:39:54:ad:62   -66  UCD Wireless
#  3   a0:b4:39:33:29:e2   -53  UCD Wireless
#  4   a0:b4:39:33:29:e1   -53       eduroam
#  5   a0:b4:39:33:29:ee   -45       eduroam
#  6   3c:51:0e:ac:e9:0e   -58       eduroam
#  7   3c:51:0e:ac:e9:0d   -57  UCD Wireless
#  8   a0:b4:39:54:ad:6d   -66  UCD Wireless
#  9   a0:b4:39:54:ad:6e   -66       eduroam
#  10  3c:51:0e:ac:e9:01   -59       eduroam
#  11  3c:51:0e:ac:e9:02   -59  UCD Wireless,
#  -3.0, 0.0.                mac_ad  rssi          ssid
#  0   a0:b4:39:33:29:ed   -44  UCD Wireless
#  1   a0:b4:39:54:ad:61   -65       eduroam
#  2   a0:b4:39:54:ad:62   -66  UCD Wireless
#  3   a0:b4:39:33:29:e2   -53  UCD Wireless
#  4   a0:b4:39:33:29:e1   -53       eduroam
#  5   a0:b4:39:33:29:ee   -45       eduroam
#  6   3c:51:0e:ac:e9:0e   -58       eduroam
#  7   3c:51:0e:ac:e9:0d   -57  UCD Wireless
#  8   a0:b4:39:54:ad:6d   -66  UCD Wireless
#  9   a0:b4:39:54:ad:6e   -66       eduroam
#  10  3c:51:0e:ac:e9:01   -59       eduroam
#  11  3c:51:0e:ac:e9:02   -59  UCD Wireless,
#  -3.0, 0.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -62  UCD Wireless
#  1  a0:b4:39:33:29:e2   -65  UCD Wireless
#  2  a0:b4:39:33:29:e1   -65       eduroam
#  3  a0:b4:39:33:29:ee   -60       eduroam
#  4  3c:51:0e:ac:e9:0e   -66       eduroam
#  5  3c:51:0e:ac:e9:0d   -66  UCD Wireless
#  6  3c:51:0e:ac:e9:01   -67       eduroam
#  7  3c:51:0e:ac:e9:02   -67  UCD Wireless,
#  -2.0, 0.0.                mac_ad  rssi          ssid
#  0   a0:b4:39:33:29:ed   -51  UCD Wireless
#  1   a0:b4:39:54:ad:61   -68       eduroam
#  2   a0:b4:39:54:ad:62   -68  UCD Wireless
#  3   a0:b4:39:33:29:e2   -50  UCD Wireless
#  4   a0:b4:39:33:29:e1   -50       eduroam
#  5   a0:b4:39:33:29:ee   -56       eduroam
#  6   3c:51:0e:ac:e9:0e   -57       eduroam
#  7   3c:51:0e:ac:e9:0d   -58  UCD Wireless
#  8   a0:b4:39:54:ad:6d   -65  UCD Wireless
#  9   a0:b4:39:54:ad:6e   -65       eduroam
#  10  3c:51:0e:ac:e9:01   -62       eduroam
#  11  3c:51:0e:ac:e9:02   -62  UCD Wireless,
#  -2.0, 0.0.                mac_ad  rssi          ssid
#  0   a0:b4:39:33:29:ed   -51  UCD Wireless
#  1   a0:b4:39:54:ad:61   -68       eduroam
#  2   a0:b4:39:54:ad:62   -68  UCD Wireless
#  3   a0:b4:39:33:29:e2   -50  UCD Wireless
#  4   a0:b4:39:33:29:e1   -50       eduroam
#  5   a0:b4:39:33:29:ee   -56       eduroam
#  6   3c:51:0e:ac:e9:0e   -57       eduroam
#  7   3c:51:0e:ac:e9:0d   -58  UCD Wireless
#  8   a0:b4:39:54:ad:6d   -65  UCD Wireless
#  9   a0:b4:39:54:ad:6e   -65       eduroam
#  10  3c:51:0e:ac:e9:01   -62       eduroam
#  11  3c:51:0e:ac:e9:02   -62  UCD Wireless,
#  -2.0, 0.0.                mac_ad  rssi          ssid
#  0   a0:b4:39:33:29:ed   -46  UCD Wireless
#  1   a0:b4:39:54:ad:61   -69       eduroam
#  2   a0:b4:39:33:29:e2   -55  UCD Wireless
#  3   a0:b4:39:33:29:e1   -54       eduroam
#  4   a0:b4:39:33:29:ee   -47       eduroam
#  5   3c:51:0e:ac:e9:0e   -59       eduroam
#  6   3c:51:0e:ac:e9:0d   -59  UCD Wireless
#  7   a0:b4:39:54:ad:6d   -61  UCD Wireless
#  8   a0:b4:39:54:ad:6e   -62       eduroam
#  9   3c:51:0e:ac:e9:01   -58       eduroam
#  10  3c:51:0e:ac:e9:02   -58  UCD Wireless,
#  -2.0, 0.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -46  UCD Wireless
#  1  a0:b4:39:33:29:e2   -55  UCD Wireless
#  2  a0:b4:39:33:29:e1   -54       eduroam
#  3  a0:b4:39:33:29:ee   -47       eduroam
#  4  3c:51:0e:ac:e9:0e   -59       eduroam
#  5  3c:51:0e:ac:e9:0d   -59  UCD Wireless
#  6  a0:b4:39:54:ad:6d   -61  UCD Wireless
#  7  a0:b4:39:54:ad:6e   -62       eduroam
#  8  3c:51:0e:ac:e9:01   -58       eduroam
#  9  3c:51:0e:ac:e9:02   -58  UCD Wireless,
#  -1.0, 0.0.                mac_ad  rssi          ssid
#  0   a0:b4:39:33:29:ed   -54  UCD Wireless
#  1   a0:b4:39:54:ad:61   -67       eduroam
#  2   a0:b4:39:54:ad:62   -69  UCD Wireless
#  3   a0:b4:39:33:29:e2   -54  UCD Wireless
#  4   a0:b4:39:33:29:e1   -57       eduroam
#  5   a0:b4:39:33:29:ee   -51       eduroam
#  6   3c:51:0e:ac:e9:0e   -64       eduroam
#  7   3c:51:0e:ac:e9:0d   -63  UCD Wireless
#  8   a0:b4:39:54:ad:6d   -65  UCD Wireless
#  9   a0:b4:39:54:ad:6e   -66       eduroam
#  10  3c:51:0e:ac:e9:01   -67       eduroam
#  11  3c:51:0e:ac:e9:02   -68  UCD Wireless,
#  -1.0, 0.0.                mac_ad  rssi          ssid
#  0   a0:b4:39:33:29:ed   -54  UCD Wireless
#  1   a0:b4:39:54:ad:61   -67       eduroam
#  2   a0:b4:39:54:ad:62   -69  UCD Wireless
#  3   a0:b4:39:33:29:e2   -54  UCD Wireless
#  4   a0:b4:39:33:29:e1   -57       eduroam
#  5   a0:b4:39:33:29:ee   -51       eduroam
#  6   3c:51:0e:ac:e9:0e   -64       eduroam
#  7   3c:51:0e:ac:e9:0d   -63  UCD Wireless
#  8   a0:b4:39:54:ad:6d   -65  UCD Wireless
#  9   a0:b4:39:54:ad:6e   -66       eduroam
#  10  3c:51:0e:ac:e9:01   -67       eduroam
#  11  3c:51:0e:ac:e9:02   -68  UCD Wireless,
#  -1.0, 0.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -49  UCD Wireless
#  1  a0:b4:39:33:29:e2   -61  UCD Wireless
#  2  a0:b4:39:33:29:e1   -59       eduroam
#  3  a0:b4:39:33:29:ee   -50       eduroam
#  4  3c:51:0e:ac:e9:0e   -63       eduroam
#  5  a0:b4:39:54:ad:6d   -63  UCD Wireless
#  6  3c:51:0e:ac:e9:0d   -63  UCD Wireless
#  7  a0:b4:39:54:ad:6e   -63       eduroam
#  8  3c:51:0e:ac:e9:01   -70       eduroam
#  9  3c:51:0e:ac:e9:02   -70  UCD Wireless,
#  -1.0, 0.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -49  UCD Wireless
#  1  a0:b4:39:33:29:e2   -61  UCD Wireless
#  2  a0:b4:39:33:29:e1   -59       eduroam
#  3  a0:b4:39:33:29:ee   -50       eduroam
#  4  3c:51:0e:ac:e9:0e   -63       eduroam
#  5  a0:b4:39:54:ad:6d   -63  UCD Wireless
#  6  3c:51:0e:ac:e9:0d   -63  UCD Wireless
#  7  a0:b4:39:54:ad:6e   -63       eduroam
#  8  3c:51:0e:ac:e9:01   -70       eduroam
#  9  3c:51:0e:ac:e9:02   -70  UCD Wireless,
#  0.0, 0.0.                mac_ad  rssi          ssid
#  0   a0:b4:39:33:29:ed   -53  UCD Wireless
#  1   a0:b4:39:54:ad:61   -69       eduroam
#  2   a0:b4:39:54:ad:62   -69  UCD Wireless
#  3   a0:b4:39:33:29:e2   -62  UCD Wireless
#  4   a0:b4:39:33:29:e1   -61       eduroam
#  5   a0:b4:39:33:29:ee   -54       eduroam
#  6   3c:51:0e:ac:e9:0e   -68       eduroam
#  7   a0:b4:39:54:ad:6d   -64  UCD Wireless
#  8   3c:51:0e:ac:e9:0d   -68  UCD Wireless
#  9   a0:b4:39:54:ad:6e   -64       eduroam
#  10  3c:51:0e:ac:e9:01   -61       eduroam
#  11  3c:51:0e:ac:e9:02   -61  UCD Wireless,
#  0.0, 0.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -53  UCD Wireless
#  1  a0:b4:39:54:ad:61   -69       eduroam
#  2  a0:b4:39:54:ad:62   -69  UCD Wireless
#  3  a0:b4:39:33:29:e2   -62  UCD Wireless
#  4  a0:b4:39:33:29:e1   -61       eduroam
#  5  a0:b4:39:33:29:ee   -54       eduroam
#  6  3c:51:0e:ac:e9:0e   -68       eduroam
#  7  3c:51:0e:ac:e9:0d   -68  UCD Wireless
#  8  3c:51:0e:ac:e9:01   -61       eduroam
#  9  3c:51:0e:ac:e9:02   -61  UCD Wireless,
#  0.0, 0.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -54  UCD Wireless
#  1  a0:b4:39:33:29:e2   -62  UCD Wireless
#  2  a0:b4:39:33:29:e1   -60       eduroam
#  3  a0:b4:39:33:29:ee   -56       eduroam
#  4  3c:51:0e:ac:e9:0e   -64       eduroam
#  5  3c:51:0e:ac:e9:0d   -64  UCD Wireless
#  6  a0:b4:39:54:ad:6d   -69  UCD Wireless
#  7  a0:b4:39:54:ad:6e   -70       eduroam,
#  0.0, 0.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -54  UCD Wireless
#  1  a0:b4:39:33:29:e2   -62  UCD Wireless
#  2  a0:b4:39:33:29:e1   -60       eduroam
#  3  a0:b4:39:33:29:ee   -56       eduroam
#  4  3c:51:0e:ac:e9:0e   -64       eduroam
#  5  3c:51:0e:ac:e9:0d   -64  UCD Wireless
#  6  a0:b4:39:54:ad:6d   -69  UCD Wireless
#  7  a0:b4:39:54:ad:6e   -70       eduroam,
#  1.0, 0.0.                mac_ad  rssi          ssid
#  0   a0:b4:39:33:29:ed   -61  UCD Wireless
#  1   a0:b4:39:37:31:02   -66  UCD Wireless
#  2   a0:b4:39:37:31:01   -66       eduroam
#  3   a0:b4:39:33:29:e2   -64  UCD Wireless
#  4   a0:b4:39:33:29:e1   -64       eduroam
#  5   a0:b4:39:33:29:ee   -61       eduroam
#  6   3c:51:0e:ac:e9:0e   -70       eduroam
#  7   a0:b4:39:54:ad:6d   -67  UCD Wireless
#  8   3c:51:0e:ac:e9:0d   -69  UCD Wireless
#  9   a0:b4:39:54:ad:6e   -67       eduroam
#  10  3c:51:0e:ac:e9:01   -65       eduroam
#  11  3c:51:0e:ac:e9:02   -63  UCD Wireless,
#  1.0, 0.0.                mac_ad  rssi          ssid
#  0   a0:b4:39:33:29:ed   -61  UCD Wireless
#  1   a0:b4:39:37:31:02   -66  UCD Wireless
#  2   a0:b4:39:37:31:01   -66       eduroam
#  3   a0:b4:39:33:29:e2   -64  UCD Wireless
#  4   a0:b4:39:33:29:e1   -64       eduroam
#  5   a0:b4:39:33:29:ee   -61       eduroam
#  6   3c:51:0e:ac:e9:0e   -70       eduroam
#  7   a0:b4:39:54:ad:6d   -67  UCD Wireless
#  8   3c:51:0e:ac:e9:0d   -69  UCD Wireless
#  9   a0:b4:39:54:ad:6e   -67       eduroam
#  10  3c:51:0e:ac:e9:01   -65       eduroam
#  11  3c:51:0e:ac:e9:02   -63  UCD Wireless,
#  1.0, 0.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -56  UCD Wireless
#  1  a0:b4:39:33:29:e2   -66  UCD Wireless
#  2  a0:b4:39:33:29:e1   -66       eduroam
#  3  a0:b4:39:33:29:ee   -60       eduroam
#  4  3c:51:0e:ac:e9:0e   -69       eduroam
#  5  a0:b4:39:54:ad:6d   -69  UCD Wireless
#  6  3c:51:0e:ac:e9:0d   -69  UCD Wireless
#  7  a0:b4:39:54:ad:6e   -68       eduroam,
#  1.0, 0.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -56  UCD Wireless
#  1  a0:b4:39:33:29:e2   -66  UCD Wireless
#  2  a0:b4:39:33:29:e1   -66       eduroam
#  3  a0:b4:39:33:29:ee   -60       eduroam
#  4  3c:51:0e:ac:e9:0e   -69       eduroam
#  5  a0:b4:39:54:ad:6d   -69  UCD Wireless
#  6  3c:51:0e:ac:e9:0d   -69  UCD Wireless
#  7  a0:b4:39:54:ad:6e   -68       eduroam,
#  2.0, 0.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -62  UCD Wireless
#  1  a0:b4:39:37:31:02   -66  UCD Wireless
#  2  a0:b4:39:37:31:01   -66       eduroam
#  3  a0:b4:39:33:29:e2   -65  UCD Wireless
#  4  a0:b4:39:33:29:e1   -67       eduroam
#  5  a0:b4:39:33:29:ee   -57       eduroam
#  6  a0:b4:39:54:ad:6d   -67  UCD Wireless
#  7  a0:b4:39:54:ad:6e   -67       eduroam,
#  2.0, 0.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -62  UCD Wireless
#  1  a0:b4:39:37:31:02   -66  UCD Wireless
#  2  a0:b4:39:37:31:01   -66       eduroam
#  3  a0:b4:39:33:29:e2   -65  UCD Wireless
#  4  a0:b4:39:33:29:e1   -67       eduroam
#  5  a0:b4:39:33:29:ee   -57       eduroam,
#  2.0, 0.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -62  UCD Wireless
#  1  a0:b4:39:33:29:e2   -67  UCD Wireless
#  2  a0:b4:39:33:29:e1   -67       eduroam
#  3  a0:b4:39:33:29:ee   -58       eduroam
#  4  a0:b4:39:54:ad:6d   -67  UCD Wireless
#  5  a0:b4:39:54:ad:6e   -67       eduroam,
#  3.0, 0.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -62  UCD Wireless
#  1  a0:b4:39:33:29:e2   -67  UCD Wireless
#  2  a0:b4:39:33:29:e1   -67       eduroam
#  3  a0:b4:39:33:29:ee   -58       eduroam
#  4  a0:b4:39:54:ad:6d   -67  UCD Wireless
#  5  a0:b4:39:54:ad:6e   -67       eduroam,
#  3.0, 0.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -62  UCD Wireless
#  1  a0:b4:39:33:29:e2   -63  UCD Wireless
#  2  a0:b4:39:33:29:e1   -63       eduroam
#  3  a0:b4:39:33:29:ee   -60       eduroam
#  4  a0:b4:39:54:ad:6d   -70  UCD Wireless
#  5  3c:51:0e:ac:e9:01   -70       eduroam
#  6  3c:51:0e:ac:e9:02   -70  UCD Wireless,
#  3.0, 0.0.               mac_ad  rssi          ssid
#  0  a0:b4:39:33:29:ed   -62  UCD Wireless
#  1  a0:b4:39:33:29:e2   -63  UCD Wireless
#  2  a0:b4:39:33:29:e1   -63       eduroam
#  3  a0:b4:39:33:29:ee   -60       eduroam
#  4  3c:51:0e:ac:e9:01   -70       eduroam
#  5  3c:51:0e:ac:e9:02   -70  UCD Wireless]

# %%
####Averages rssi of matching mac address for each grid point

#Adds or appends rssi values to mac address keys
def wifiToDict(row, Dict):
    #if mac_ad is already in dict, then append the rssi, else add the mac_ad
    if (row["mac_ad"] in Dict):
        Dict.get(row["mac_ad"]).append(row["rssi"])
    else:
         Dict[row["mac_ad"]] = [row["rssi"]]

currX = gridPointsList[0].X
currY = gridPointsList[0].Y
gridCoordsList = [GridPoint(currX, currY)]
wifi_dict = {}
dictionariedGridPointsList = []
#Makes a list of dictionaries that have a list of rssis from matching coords and matching mac addresses
for i in range(len(gridPointsList)):
    if ((currX == gridPointsList[i].X and currY == gridPointsList[i].Y) == False):
        dictionariedGridPointsList.append(wifi_dict)
        wifi_dict = {}
        currX = gridPointsList[i].X
        currY = gridPointsList[i].Y
        gridCoordsList.append(GridPoint(currX, currY))
    
    df = gridPointsList[i].df
    for j, row in df.iterrows():
        wifiToDict(row, wifi_dict)
        
dictionariedGridPointsList.append(wifi_dict)
#print(dictionariedGridPointsList)


#Averages the list of rssis for each mac address
averagedGridPointsList = []
for i in range(len(dictionariedGridPointsList)):
        
    temp_dict = {}
    for item in dictionariedGridPointsList[i].items():
        if (len(item[1]) > limit_number):
            temp_dict[item[0]] =  sum(item[1])/len(item[1])
        else:
            dictionariedGridPointsList[i].pop(item[0])
            break
        #print(f"{i}, {item[0]}, {item[1]}")
    
    mac_ads = temp_dict.keys()
    rssis = temp_dict.values()
    averagedGridPointsList.append(GridPoint(gridCoordsList[i].X, gridCoordsList[i].Y, pd.DataFrame(list(zip(mac_ads, rssis)), columns=["mac_ad", "rssi"])))  
    
averagedGridPointsList[27].df
# Out:
#               mac_ad       rssi
# 0  a0:b4:39:33:29:ed -62.000000
# 1  a0:b4:39:33:29:e2 -64.333333
# 2  a0:b4:39:33:29:e1 -64.333333
# 3  a0:b4:39:33:29:ee -59.333333

# %% [markdown]
# ## Trial Data (Acceleration, heading etc)

# %%
data = ET.parse("Trial10.xml")
TrialDataRoot = data.getroot()

# %%
dataPointsList = []
for dataPoint in TrialDataRoot:
    wifi = []
    for wifiPoint in dataPoint.find("wifi"):
        if (int(wifiPoint.text) < lowerLimit):
            continue
        wifi.append({"mac_ad": wifiPoint.attrib.get("mac_ad"), 
         "rssi": int(wifiPoint.text), 
         "ssid": wifiPoint.attrib.get("ssid")})
        
    dataPointsList.append(
        {
            "Acceleration": float(dataPoint.find("acceleration").text),
            "Heading": float(dataPoint.find("heading").text),
            "Timestamp": float(dataPoint.find("timestamp").text),
            "Wifi": wifi
        }
    )
    
df = pd.DataFrame(dataPointsList)

# %%
#Modifying Data
df["Time Elapsed"] = ((df["Timestamp"]-df["Timestamp"][0])/1000000)
df["Acceleration"] = df["Acceleration"]-9.8
df["Heading"] = df["Heading"] - df["Heading"][0]
df
# Out:
#       Acceleration     Heading     Timestamp Wifi  Time Elapsed
# 0        -0.232228    0.000000  5.574053e+12   []      0.000000
# 1         0.333068    0.073541  5.574072e+12   []     19.057002
# 2         0.532064    0.022184  5.574091e+12   []     38.113920
# 3         0.772587   -0.093608  5.574110e+12   []     57.171096
# 4         0.760338   -0.231243  5.574129e+12   []     76.228112
# ...            ...         ...           ...  ...           ...
# 1548     -2.128944 -185.977957  5.603553e+12   []  29500.098645
# 1549     -1.510123 -185.672361  5.603572e+12   []  29519.155594
# 1550     -0.899961 -185.230250  5.603591e+12   []  29538.212582
# 1551     -0.658768 -184.659143  5.603610e+12   []  29557.269478
# 1552     -0.205482 -183.991772  5.603629e+12   []  29576.326611
#
# [1553 rows x 5 columns]

# %% [markdown]
# # Predicting Coordinates

# %%
wifi_data = df[df["Wifi"].str.len() != 0]
wifi_data
# Out:
#       Acceleration     Heading     Timestamp  \
# 262      -0.035532    7.340404  5.579046e+12
# 472       0.043977   -4.484265  5.583048e+12
# 682      -0.465975    4.930809  5.587050e+12
# 892       2.395739   18.108191  5.591051e+12
# 1102     -0.777061 -185.868387  5.595053e+12
# 1312      0.947411 -209.049558  5.599055e+12
# 1522      0.198639 -184.154509  5.603057e+12
#
#                                                    Wifi  Time Elapsed
# 262   [{'mac_ad': 'a0:b4:39:33:29:ed', 'rssi': -54, ...   4992.954302
# 472   [{'mac_ad': 'a0:b4:39:33:29:ed', 'rssi': -56, ...   8994.924693
# 682   [{'mac_ad': 'a0:b4:39:33:29:ed', 'rssi': -56, ...  12996.876850
# 892   [{'mac_ad': 'a0:b4:39:33:29:ed', 'rssi': -51, ...  16998.817827
# 1102  [{'mac_ad': 'a0:b4:39:33:29:ed', 'rssi': -51, ...  21000.752446
# 1312  [{'mac_ad': 'a0:b4:39:33:29:ed', 'rssi': -56, ...  25002.683207
# 1522  [{'mac_ad': 'a0:b4:39:33:29:ed', 'rssi': -56, ...  29004.617586

# %%
#Number K in KNN
K = 3
ListInUse = gridPointsList#options: gridPointsList or averagedGridPointsList
#Go Through all the Data Points
for i, dataPoint in wifi_data.iterrows():
    #Collect the cumulative error between every dataPoint and gridPoint
    errors = []
    for gridPoint in gridPointsList:
        #Converting corressponding points to key-value pair data structure with mac_ad as key and rssi and value
        grid_dict = gridPoint.df.set_index("mac_ad").to_dict()["rssi"]
        data_dict = pd.DataFrame(dataPoint["Wifi"]).set_index("mac_ad").to_dict()["rssi"]
        
        #Calculate Cumulative Error
        error = 0
        for key, value in data_dict.items():
            if key in grid_dict:#If keys match, calculate difference and add to cumultive error. #Ignore keys that don't match
                error += abs(int(grid_dict[key]) - int(value))
            #else: error += 100
        errors.append({"error": error,
                      "X": gridPoint.X,
                      "Y": gridPoint.Y})
        
    #Sort list by the ascending error
    sorted_list = sorted(errors, key=lambda k: k["error"])
    sorted_list = sorted_list[0:K]
    print(sorted_list)
    
    #Calculate Average distance between the 3 grid points of least error
    x = 0
    y = 0
    for point in sorted_list:
        x += float(point["X"])
        y += float(point["Y"])
    x /= K
    y /= K
    
    #Put Predicted coordinates into original data df
    df.at[i, "Predicted X"] = x
    df.at[i, "Predicted Y"] = y
    print(f"Predicted Coordinates: {x},{y}\n\n")

completed_df = df
# Out:
# [{'error': 4, 'X': '3.0', 'Y': '-1.0'}, {'error': 4, 'X': '3.0', 'Y': '-1.0'}, {'error': 5, 'X': '3.0', 'Y': '-3.0'}]
# Predicted Coordinates: 3.0,-1.6666666666666667
#
#
# [{'error': 1, 'X': '0.0', 'Y': '-3.0'}, {'error': 2, 'X': '3.0', 'Y': '-1.0'}, {'error': 4, 'X': '3.0', 'Y': '-1.0'}]
# Predicted Coordinates: 2.0,-1.6666666666666667
#
#
# [{'error': 1, 'X': '0.0', 'Y': '-3.0'}, {'error': 2, 'X': '3.0', 'Y': '-1.0'}, {'error': 4, 'X': '3.0', 'Y': '-1.0'}]
# Predicted Coordinates: 2.0,-1.6666666666666667
#
#
# [{'error': 2, 'X': '0.0', 'Y': '-2.0'}, {'error': 2, 'X': '0.0', 'Y': '-2.0'}, {'error': 3, 'X': '3.0', 'Y': '-3.0'}]
# Predicted Coordinates: 1.0,-2.3333333333333335
#
#
# [{'error': 2, 'X': '0.0', 'Y': '-2.0'}, {'error': 2, 'X': '0.0', 'Y': '-2.0'}, {'error': 3, 'X': '3.0', 'Y': '-3.0'}]
# Predicted Coordinates: 1.0,-2.3333333333333335
#
#
# [{'error': 2, 'X': '0.0', 'Y': '-3.0'}, {'error': 3, 'X': '0.0', 'Y': '-3.0'}, {'error': 3, 'X': '-2.0', 'Y': '-2.0'}]
# Predicted Coordinates: -0.6666666666666666,-2.6666666666666665
#
#
# [{'error': 2, 'X': '0.0', 'Y': '-3.0'}, {'error': 3, 'X': '0.0', 'Y': '-3.0'}, {'error': 3, 'X': '-2.0', 'Y': '-2.0'}]
# Predicted Coordinates: -0.6666666666666666,-2.6666666666666665

# %%
completed_df
# Out:
#       Acceleration     Heading     Timestamp Wifi  Time Elapsed  Predicted X  \
# 0        -0.232228    0.000000  5.574053e+12   []      0.000000          NaN
# 1         0.333068    0.073541  5.574072e+12   []     19.057002          NaN
# 2         0.532064    0.022184  5.574091e+12   []     38.113920          NaN
# 3         0.772587   -0.093608  5.574110e+12   []     57.171096          NaN
# 4         0.760338   -0.231243  5.574129e+12   []     76.228112          NaN
# ...            ...         ...           ...  ...           ...          ...
# 1548     -2.128944 -185.977957  5.603553e+12   []  29500.098645          NaN
# 1549     -1.510123 -185.672361  5.603572e+12   []  29519.155594          NaN
# 1550     -0.899961 -185.230250  5.603591e+12   []  29538.212582          NaN
# 1551     -0.658768 -184.659143  5.603610e+12   []  29557.269478          NaN
# 1552     -0.205482 -183.991772  5.603629e+12   []  29576.326611          NaN
#
#       Predicted Y
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 1548          NaN
# 1549          NaN
# 1550          NaN
# 1551          NaN
# 1552          NaN
#
# [1553 rows x 7 columns]

# %% [markdown]
# # Step Detection

# %%
df_accel = df.copy(deep=True)
plt.figure(figsize=(20,5))
plt.plot(df_accel["Time Elapsed"], df_accel["Acceleration"])
plt.xlabel("Time Elapsed")
plt.ylabel("Acceleration")
plt.show()

# %%
#Do Thresholds
base = 0
margin = 0.6
rolling_mean_window = 6

high_thres = base+margin
low_thres = base-margin

#Smooth the Graph with rolling mean
rolling = df_accel["Acceleration"].rolling(window=rolling_mean_window)
rolling_mean = rolling.mean()
df_accel["Smooth Accel"] = rolling_mean

X = df_accel["Time Elapsed"]
Y = df_accel["Smooth Accel"]

plt.figure(figsize=(20,5))
plt.plot(X, Y)
plt.xlabel("Time Elapsed")
plt.ylabel("Acceleration")
plt.axhline(y=base, color="green", linestyle='--')
plt.axhline(y=high_thres, color="red", linestyle=':')
plt.axhline(y=low_thres, color="red", linestyle=':')
plt.show()

# %%
valleys_indexes = (np.diff(np.sign(np.diff(Y))) > 0).nonzero()[0] + 1      # local min
peaks_indexes = (np.diff(np.sign(np.diff(Y))) < 0).nonzero()[0] + 1       # local max
# +1 due to the fact that diff reduces the original index number

v_x = X[valleys_indexes].reset_index(drop=True)#valleys x values
p_x = X[peaks_indexes].reset_index(drop=True)#peaks x values
v_y = Y[valleys_indexes].reset_index(drop=True)#valleys y values
p_y = Y[peaks_indexes].reset_index(drop=True)#valleys y values

#If the first point is a peak, remove that peak and let valleys go first
if p_x[0] < v_x[0]:
    p_x = p_x.drop(index=p_x.index[0], axis=0).reset_index(drop=True)
    p_y = p_y.drop(index=p_y.index[0], axis=0).reset_index(drop=True)
    
detected_steps = []
for i in range(min(len(v_x),len(p_x))):
    v = [v_x[i], v_y[i]]
    p = [p_x[i], p_y[i]] 
    x1 = v[0]
    x2 = p[0]
    y1 = v[1]
    y2 = p[1]
    if y1 < low_thres and y2 > high_thres:
        m = ((y2-y1)/(x2-x1))
        c = -(m*x1)+y1
        detected_steps.append(-c/m)
        #print(f"{v}, {p}, {(-(m*-x1)+(y1))/m}")
        
len(detected_steps)
# Out:
# 27

# %%
fig = plt.figure(figsize=(20,5))
ax = fig.add_subplot(1, 1, 1)
minor_tick = []
for i in range(0, int(max(p_x)), 1000):
    minor_tick.append(i)
plt.plot(X, Y)
plt.xlabel("Time Elapsed")
plt.ylabel("Acceleration")
ax.set_xticks(minor_tick, minor=True)
plt.grid(axis="x", which="both")
plt.scatter(x=v_x, y=v_y, color="red")
plt.scatter(x=p_x, y=p_y, color="green")
plt.axhline(y=base, color="green", linestyle='--')
plt.axhline(y=high_thres, color="red", linestyle=':')
plt.axhline(y=low_thres, color="red", linestyle=':')
for i in detected_steps:
    plt.axvline(x=i, color="purple", linestyle=":")
plt.show()

# %%
step_counter = 0
completed_df["Step Detected"] = False
for i, row in completed_df.iterrows():
    if len(detected_steps) == step_counter:
        break
    #If Step detected at this time point, then
    if row["Time Elapsed"] >= detected_steps[step_counter]:
        completed_df.loc[i, ("Step Detected")]= True
        step_counter += 1
completed_df
# Out:
#       Acceleration     Heading     Timestamp Wifi  Time Elapsed  Predicted X  \
# 0        -0.232228    0.000000  5.574053e+12   []      0.000000          NaN
# 1         0.333068    0.073541  5.574072e+12   []     19.057002          NaN
# 2         0.532064    0.022184  5.574091e+12   []     38.113920          NaN
# 3         0.772587   -0.093608  5.574110e+12   []     57.171096          NaN
# 4         0.760338   -0.231243  5.574129e+12   []     76.228112          NaN
# ...            ...         ...           ...  ...           ...          ...
# 1548     -2.128944 -185.977957  5.603553e+12   []  29500.098645          NaN
# 1549     -1.510123 -185.672361  5.603572e+12   []  29519.155594          NaN
# 1550     -0.899961 -185.230250  5.603591e+12   []  29538.212582          NaN
# 1551     -0.658768 -184.659143  5.603610e+12   []  29557.269478          NaN
# 1552     -0.205482 -183.991772  5.603629e+12   []  29576.326611          NaN
#
#       Predicted Y  Step Detected
# 0             NaN          False
# 1             NaN          False
# 2             NaN          False
# 3             NaN          False
# 4             NaN          False
# ...           ...            ...
# 1548          NaN          False
# 1549          NaN          False
# 1550          NaN          False
# 1551          NaN          False
# 1552          NaN          False
#
# [1553 rows x 8 columns]

# %% [markdown]
# # Particle Filter

# %%
import pandas as pd
import numpy as np
from numpy import random
from numpy.random import uniform
import math
import time
import plotly.express as px
import plotly.graph_objects as go

# %%
#Kernel of Particle Filter

#Return array of random particles with 3 columns. X, Y , Heading
def create_uniform_particles(x_min, x_max, y_min, y_max, N):
    particles = np.empty((N, 3))
    particles[:, 0] = uniform(x_min, x_max, size=N)
    particles[:, 1] = uniform(y_min, y_max, size=N)
    particles[:, 2] = uniform(0, 360, size=N)
    return particles
        
def apply_movement(particles, distance, heading, angle_offset, distance_std, heading_std):
    moved_particles = np.empty((len(particles), 3))
    for i in range(len(particles)):
        #Adding noise
        noisy_distance = random.normal(distance, distance_std)
        noisy_angle = random.normal(0, heading_std)
        
        #New heading direction for particle
        direction = particles[i][2] + heading + noisy_angle
        x = particles[i][0] + (noisy_distance * math.cos(((angle_offset-direction) * math.pi) / 180))
        y = particles[i][1] + (noisy_distance * math.sin(((angle_offset-direction) * math.pi) / 180))
        moved_particles[i] = [x,y,direction]
    return moved_particles


def validate_angle(angle):
    if angle >= 360:
        return angle-360
    elif angle < 0:
        return angle+360
    else:
        return angle
    

def calculate_weights(particles, predicted_location, xRange, yRange, std):
    weights = []
    
    sum = 0
    #Get Sum of distances from all particles
    for particle in particles:
            
        d = distance(particle, predicted_location)
        p = likelihood(d, std)
        if (not is_in_Bounds(particle, xRange, yRange)):
            p = 0

        weights.append(p)
        sum += p
    weights[:] = [x / sum for x in weights]

    #return likelihood for all particles each between 0 and 1, all summing to 1
    return weights

def distance(p1, p2):
    return math.sqrt((p1[0]-p2[0])**2 + (p1[1]-p2[1])**2)

def likelihood(distance, std):
    variance = std**2
    return np.exp(-0.5*(distance**2/variance))

def is_in_Bounds(p, xRange, yRange):
    return not(p[0] < xRange[0] or p[0] > xRange[1] or p[1] < yRange[0] or p[1] > yRange[1])
    
    
    
    
def resample(particles, weights, N, xRange, yRange, noise_std, angle_noise_std):
    new_particles=np.empty((N,3))

    for i in range(N):
        index = random.choice(np.arange(0,len(weights), 1), p=weights)
        x = random.normal(particles[index][0], resample_std)
        y = random.normal(particles[index][1], resample_std)
        coords = [x, y]
        while (not is_in_Bounds(coords, xRange, yRange)):
            x = random.normal(particles[index][0], noise_std)
            y = random.normal(particles[index][1], noise_std)
            coords = [x, y]
            
        #Use the selected particle's heading
        direction = random.normal(particles[index][2], angle_noise_std)
        
        new_particles[i] = [x,y,direction]
    #Return particles that tend towards the weights
    return new_particles

# %%
#Function to given necessary constants
def reset(N, x, y, xRange, yRange, step_distance, angle_offset):
    #Create random particles in random location
    particles = create_uniform_particles(xRange[0], xRange[1], yRange[0], yRange[1], N)
    #All weights for particles
    weights = np.array([1/N]*N)
    
    return N, particles, weights, x, y, xRange, yRange, step_distance, angle_offset

def update_steps_location(x ,y ,xCoords, yCoords, dist, heading, angle_offset):
    if (len(xCoords) == 0 and len(yCoords) == 0):
        x += (dist * math.cos((abs(angle_offset-heading) * math.pi) / 180))
        y += (dist * math.sin((abs(angle_offset-heading) * math.pi) / 180))
    else:
        x = xCoords[len(xCoords)-1] + (dist * math.cos(((angle_offset-heading) * math.pi) / 180))
        y = yCoords[len(yCoords)-1] + (dist * math.sin(((angle_offset-heading) * math.pi) / 180))
        
    xCoords.append(x)
    yCoords.append(y)
    return xCoords, yCoords

#Traces are the detected steps and are a reference for the real path
def plot_particles(particles, weights, xRange, yRange):
    fig = px.scatter(x=particles[:,0], y=particles[:,1],size=weights)#size=weights changes size of points
    fig.update_layout(width = 700, height = 500, xaxis_range = xRange, yaxis_range = yRange)
    return fig





#The driver code for particle filter
def particle_filter_driver_code(N, particles, weights, df, x, y, xRange, yRange, step_distance, angle_offset, step_distance_std, heading_std, weights_std, resample_std):
    test_list_x = []
    test_list_y = []
    Real_path_x = [3, -3, -3, 3, 3, -3, -3, 3, 3]
    Real_path_y = [-3, -3, 0, 0, -3, -3, 0, 0, -3]
    #Coords of where steps were detected
    xTraces = []
    yTraces = []

    last_step_heading = 0
    for i, row in df.iterrows():
        #Control Data
        #If Step detected at this time point, then apply movement
        if row["Step Detected"] == True:
            particles = apply_movement(particles, step_distance, row["Heading"]-last_step_heading, angle_offset, step_distance_std, heading_std)
            last_step_heading = row["Heading"]
            #test_list_x.append(particles[0, 0])
            #test_list_y.append(particles[0,1])
            
            #Update traces with next detected step
            xTraces, yTraces = update_steps_location(x, y, xTraces, yTraces, step_distance, row["Heading"], angle_offset)
        else: #If no steps detected, update particles' headings but not distance moved.
            last_step_heading = row["Heading"]
            particles = apply_movement(particles, 0, row["Heading"]-last_step_heading, angle_offset, 0, heading_std)
        #Observation Data
        #If predicted coords are available then apply them
        if (not math.isnan(row["Predicted X"])):
            pred_x = row["Predicted X"]
            pred_y = row["Predicted Y"]
            test_list_x.append(pred_x)
            test_list_y.append(pred_y)
            
            
            
            ##Calculate Weights for current particles, then plot how well the weights fit, then resample for next iteration
            print(f"Predicted Coords: {pred_x}, {pred_y}")
            weights = calculate_weights(particles, [pred_x, pred_y], xRange, yRange, weights_std)
            
            #Plot particles
            fig = plot_particles(particles, weights, xRange, yRange)
            fig.add_trace(go.Scatter(x=xTraces, y=yTraces, mode='lines+markers', name="Detected Steps"))
            fig.add_trace(go.Scatter(x=[pred_x], y=[pred_y], mode='lines+markers', name="Observation Data"))
            #fig.add_trace(go.Scatter(x=Real_path_x, y=Real_path_y, mode='lines+markers', name="Real Path"))
            fig.add_trace(go.Scatter(x=[3], y=[-3], mode='lines+markers', name="Starting Position"))
            #fig.add_trace(go.Scatter(x=test_list_x, y=test_list_y, mode='lines+markers'))
            fig.show()
            
            #Resample based on current weights
            particles = resample(particles, weights, N, xRange, yRange, resample_std, heading_std)
            
            
            #Slowly converge the particles
            if (weights_std > 0.25):
                weights_std = weights_std - 0.3
            if (resample_std > 0.25):
                resample_std = resample_std - 0.3

# %%
def create_articial_observation_data(x, y, heading_list, detected_steps_list, step_distance, angle_offset, step_distance_std, heading_std):
    if (len(heading_list) != len(detected_steps_list)):
        return
    observation_data_x = [x]
    observation_data_y = [y]
    for i in range(1, len(heading_list)):
        #Adding noise
        noisy_distance = 0
        if (detected_steps_list[i] == True):
            noisy_distance = random.normal(step_distance, step_distance_std)
        noisy_angle = random.normal(0, heading_std)
        
        direction = heading_list[i] + noisy_angle
        x = observation_data_x[i-1] + (noisy_distance * math.cos(((angle_offset-direction) * math.pi) / 180))
        y = observation_data_y[i-1] + (noisy_distance * math.sin(((angle_offset-direction) * math.pi) / 180))


        observation_data_x.append(x)
        observation_data_y.append(y)

    for i in range(1, len(observation_data_x)):
        if (not i % 7 == 0):
            observation_data_x[i] = np.nan
            observation_data_y[i] = np.nan
    return observation_data_x, observation_data_y



N, particles, weights, x, y, xRange, yRange, step_distance, angle_offset = reset(
    100, 4, -2.5, np.array([-10,10]), np.array([-10,10]), 0.6, 180)
#particles = create_uniform_particles(3.5, 4.5, -2, -3, N)
step_distance_std = 0.1
heading_std = 1
weights_std = 2
resample_std = 2


test_detected_steps = [False, True, True, True, True, True, False, True, False, True, True, True, True, True, True, False, True, True, True, True, True, False, True, False, True, True, True, True, True, True, True, True]#len = 15
#test_heading = [0, 0, 0 ,-30, -60, -90, -120, -160, -160, -180, -180, -200, -210, -230, -260]
test_heading = [0, 0, 0 ,-30, -30, -30, -30, -45, -50, -60, -60 , -50, -40, -30, -20, 0, 0, 0 ,30, 30, 30, 30, 45, 50, 60, 60 , 70, 80, 90, 100, 100, 100]
test_observation_x_data, test_observation_y_data = create_articial_observation_data(x ,y ,test_heading, test_detected_steps, step_distance, angle_offset, step_distance_std, heading_std)

Artificial_data_df = pd.DataFrame()
Artificial_data_df["Predicted X"] = test_observation_x_data
Artificial_data_df["Predicted Y"] = test_observation_y_data
Artificial_data_df["Step Detected"] = test_detected_steps
Artificial_data_df["Heading"] = test_heading

#Plot intial particles
fig = plot_particles(particles, weights, xRange, yRange)
fig.show()

particle_filter_driver_code(N, particles, weights, Artificial_data_df, x, y, xRange, yRange, step_distance, angle_offset, step_distance_std, heading_std, weights_std, resample_std)
Artificial_data_df
# Out:
# <div>                            <div id="95a0bba6-aa78-4fa0-b7f8-d0394bb73033" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("95a0bba6-aa78-4fa0-b7f8-d0394bb73033")) {                    Plotly.newPlot(                        "95a0bba6-aa78-4fa0-b7f8-d0394bb73033",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<br>size=%{marker.size}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","size":[0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01],"sizemode":"area","sizeref":2.5e-05,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[2.7232200547624092,-8.321001973403297,3.0207721734869093,-2.303201891332332,3.7074381192382067,-3.7990085708519334,-4.259237952187222,-2.7052514149713947,3.0966386230871272,-2.913626700669843,-0.8579628280832559,-8.758529315080814,-2.6182506527492366,5.515648418020497,-8.859204147394589,-7.868990885867824,3.1508899837968496,-5.70796907155366,-0.6225725899671009,-6.848588300322634,9.222933603184021,5.6633895583513105,6.023757518810914,7.3703794560402045,5.951055266295315,5.6294080848776,5.654639114547688,-7.912754361343513,-9.541307499121066,3.0984806410824994,0.4082922229026682,-0.5754001985849584,7.868376367277101,-4.211059752836633,-2.555443000856947,0.6482040222957313,-4.262453468279855,-6.2202821821590675,3.921432721206674,-8.442838530963638,2.431981631019939,8.374187833943427,-6.398677485490911,9.907740528900991,-1.4968817586376044,-5.0874604835051755,8.543689788869873,5.7690906296399405,3.505344115326359,-1.8260371345590602,3.3573764258736816,3.2446773275435774,8.323922241691317,0.4921548973420222,-4.4151837656597515,6.99735261052377,-0.3363727163271175,0.538941294751826,-4.639925401477991,-9.516122024064044,0.5776091436020021,5.352031026349636,5.464703023321922,1.1399326404421366,-0.010856346896122915,0.24560330679646647,1.1167458394788312,-0.836322926898184,0.7244787048840262,1.3564469495496052,5.1476254026161925,5.977954876927738,8.038095962481208,9.772707334483023,1.4121908122703335,-7.123694498687307,1.2822207030079813,-7.991118432852797,-3.0779979166642812,8.561916879166862,-8.25794840655327,3.0073175200590008,3.7654960894157625,-2.0400372730449323,4.063841595705062,-1.7786769449659623,-0.6572269072548043,9.932960144423625,9.945390891196663,-5.171917815417302,2.025962091971909,-0.4879408573110773,-7.090119396434131,-4.86218311944808,8.4357389879696,3.8598700459608146,4.739964076453138,9.012957517001293,0.9673993293831558,4.8776725012158195],"xaxis":"x","y":[-4.774624992209775,-9.913838131764747,-0.2886888499809803,-6.981631494796097,3.9657948939353656,3.9251642288418793,-9.303777664446763,-2.9416409431012047,4.565514168042515,-1.2670210735108043,-2.1484304488637784,9.761714123187108,9.780842277385926,-0.3384839852335766,7.251264017614073,-5.854611142503659,-6.719032313964357,4.66775008556275,-1.7770747560607418,2.241359288861096,-3.9938210250438573,-6.854450378015597,4.385576667884161,-6.106501293776965,6.356461613285383,7.9368332198084275,6.632809608026683,8.103996624349591,-3.6142245194045035,-2.3704768479256106,1.3479680188019998,3.067761321426607,-4.901911074586376,-4.437552804470584,6.717394797379264,3.7568494864153763,-8.454945861719303,-0.23164473220642812,-4.38476947189939,8.65537754404798,9.909046906982358,-2.7387901550377647,-4.389345510059837,-7 ...
# Predicted Coords: 4.0, -2.5
# <div>                            <div id="99b391d7-377b-4c94-92ca-3079a8783668" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("99b391d7-377b-4c94-92ca-3079a8783668")) {                    Plotly.newPlot(                        "99b391d7-377b-4c94-92ca-3079a8783668",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<br>size=%{marker.size}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","size":[0.03651016518361662,5.090834170542577e-13,0.04114092787946354,4.8372664310211736e-05,0.00045456673129995993,2.447416725331618e-07,5.195156052997125e-08,0.0003023019423098595,0.0001504547997109804,0.00017965670506096037,0.00440471675675209,8.5698480590331125e-19,2.325246835778465e-12,0.03576371222430927,6.208519791576437e-16,4.713364742359256e-10,0.008439716936601513,1.0628446179282413e-09,0.005538654898834205,2.1002733678690013e-09,0.0021367465547799474,0.005652447237638146,0.0001366621287779112,0.004064589679288141,2.9312109011003616e-06,7.487385152724586e-08,1.799666720470795e-06,1.328851401250891e-15,8.127912774027599e-12,0.07704674228085004,0.0026770049851229036,0.00012955106085566493,0.006400732195210773,1.1692002868656409e-05,9.697198602185161e-09,0.0001572786405674412,1.9982107117530355e-07,9.593410748565527e-08,0.05477781948123875,5.90593572431278e-17,2.747815584938704e-10,0.007762340987668329,7.376224574779214e-08,7.624639028891341e-05,0.00026891974086360815,2.942517640566052e-08,0.003432628578761025,5.0378824386666213e-08,0.021077716041311614,0.0006615345040648601,0.0011364342155881846,0.0006461552096810112,0.006942476114654321,5.574583363055229e-07,2.868326091671243e-08,0.003480736827955305,0.00456326824936667,0.005060459446875518,1.610130221284084e-06,3.4907416081041057e-13,0.001451278601350562,0.035150453263410035,0.05403628528954996,8.153583398658682e-06,0.01060823134556352,0.013991622743825803,0.010639675954014362,0.0007484349872634787,0.01926576753220483,0.01477977347327066,0.050162057008605807,0.0472568604394892,0.0011553506726302116,0.00099252144587016,0.0001206403230869899,2.394304501561118e-13,0.004065634531900169,1.7779434480860396e-10,4.2287937386730905e-06,0.006253828795018009,1.749717862178775e-10,0.0624843788726533,0.08147932064025015,9.795744590899722e-06,0.08469994656123843,4.342240427887638e-05,0.005432840479626444,0.00044440349915115065,0.0007135662240088457,7.6681923783107e-13,0.0009506695466074101,0.0022883083043132232,1.5256682059336207e-08,9.40015131398723e-07,1.9879169512411065e-06,0.07366808025724159,1.8437358659787223e-05,0.002335302373148209,0.0011402345281225088,0.07235635994713621],"sizemode":"area","sizeref":0.00021174986640309609,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[2.7232200547624092,-8.321001973403297,3.0207721734869093,-2.303201891332332,3.7074381192382067,-3.7990085708519334,-4.259237952187222,-2.7052514149713947,3.0966386230871272,-2.913626700669843,-0.8579628280832559,-8.758529315080814,-2.6182506527492366,5.515648418020497,-8.859204147394589,-7.868990885867824,3.1508899837968496,-5.70796907155366,-0.6225725899671009,-6.848588300322634,9.222933603184021,5.6633895583513105,6.023757518810914,7.3703794560402045,5.951055266295315,5.6294080848776,5.654639114547688,-7.912754361343513,-9.541307499121066,3.0984806410824994,0.4082922229026682,-0.5754001985849584,7.868376367277101,-4.211059752836633,-2.555443000856947,0.6482040222957313,-4.262453468279855,-6.2202821821590675,3.921432721206674,-8.442838530963638,2.431981631019939,8.374187833943427,-6.398677485490911,9.907740528900991,-1.4968817586376044,-5.0874604835051755,8.543689788869873,5.7690906296399405,3.505344115326359,-1.8260371345590602,3.3573764258736816,3.2446773275435774,8.323922241691317,0.4921548973420222,-4.4151837656597515,6.997 ...
# Predicted Coords: 0.6120751552895254, -3.761347101916285
# <div>                            <div id="5b98a65c-5aeb-4aca-a135-e07db1249c5e" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5b98a65c-5aeb-4aca-a135-e07db1249c5e")) {                    Plotly.newPlot(                        "5b98a65c-5aeb-4aca-a135-e07db1249c5e",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<br>size=%{marker.size}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","size":[0.003289706888344113,0.0278073926110608,0.0006564376293898043,2.730331989782242e-06,0.0010547427806903054,1.0063204948205122e-05,1.3454339270997605e-08,3.2651180424026953e-07,8.850066169503627e-09,0.0001884212899335695,0.0006855896104204525,0.014039980417992823,0.008045505060122157,0.023864081932236197,0.005012790695247413,0.021745580940604615,0.002398590099191017,2.947483737429904e-09,2.5053147107177628e-05,0.0008054562400340231,0.0007486357644564197,0.0,1.653539738662802e-05,2.6593811135910154e-08,1.0321557335040418e-07,1.5829637321300066e-07,4.4203444470290336e-05,2.89398721105385e-06,0.07064906066584092,5.7662137606959184e-05,0.0010390065603877324,1.3799486559441761e-08,0.030066524382027948,0.001431202883820893,7.783797339049529e-10,0.007578023044492397,9.451970755639839e-09,3.696584324410453e-08,0.0015930262047956234,0.0014241548188636828,0.03684130467726202,0.0052435818414983,0.02279664643475016,1.0720909004236195e-06,0.04166358902328978,0.012249011755201064,0.050693011508483245,0.0016893779244606544,4.7920699593396006e-05,0.00025930144657692337,3.6881396488010806e-07,9.508242672953222e-07,0.0019632555271291026,0.0020923860943067927,1.2842336716871222e-06,0.00014425366508248304,0.0022480535668438204,6.403233583386722e-06,1.6840454278976945e-08,0.014885275147663704,0.07992063206182166,8.158210883389478e-06,0.0,0.0023015242171138487,0.00510924239377973,7.252828070905763e-09,1.2893504451365318e-06,0.0015720052884689644,0.032483996081844026,9.261085641447357e-09,0.06874095959166948,0.01398215518027707,7.437585138406682e-05,7.71935762747572e-06,0.058459770052370685,0.00020609870523982855,0.08267956671801581,5.6572031573185865e-05,7.637297137891893e-05,1.3562991354279636e-06,0.006525525898236764,2.2294413580809553e-06,0.008838974322210915,0.0001715731287612155,0.0008936421434770297,0.002980945200119242,0.007555461088796882,0.0025223112940478435,0.012021114693707601,0.00011168440404925976,0.0016274907001202017,3.334601403895307e-07,0.004072871544413722,0.07830240364302878,1.020815723845023e-05,5.595732030014928e-05,0.0021005388403957156,0.0015017019704852543,0.04370470359503726,0.06420769989234441],"sizemode":"area","sizeref":0.00020669891679503952,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[1.1448631028189005,-1.7984100865410846,5.463440534608502,4.482076841816613,2.633921796850113,3.6578218680767884,4.7895615216357905,9.093364546456106,7.994227828876426,6.45095788771595,3.1922092602692183,3.754436854858553,1.2343041967397745,2.8622773004983117,4.460286847992241,2.233459067572471,5.050276772331877,6.415981139142839,7.390347159476277,-2.3832202130946785,5.498828926374432,10.244905913795384,6.856916189464982,2.199090550170739,9.105164939786382,5.521426287451771,5.715503504837459,8.092919974867549,1.0702874759598426,6.1765672773519595,4.838361494497361,9.223964764335618,-1.642164794498693,3.6560402390089477,3.7830878246871613,4.317982183950582,9.1534832737615,5.5508512174979,2.971355758399286,0.7547902706599554,2.4556213837984764,3.8344546918885394,2.830659111104312,4.805414073668493,2.6048471760102863,3.8446768765258947,2.1520029974589767,0.34340140025098953,5.387232029127991,6.276674252159577,8.896370717673559,8.430678370784733,4.513585503139353,1.3173833331297167,8.327566297386621,5.761513012974901,-0.5081811019893,5.814726913925233,5.66 ...
# Predicted Coords: -1.9780077978966935, -6.203272837589129
# <div>                            <div id="dbb323c1-fe39-40a3-8bee-e8a7db8ca8e3" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dbb323c1-fe39-40a3-8bee-e8a7db8ca8e3")) {                    Plotly.newPlot(                        "dbb323c1-fe39-40a3-8bee-e8a7db8ca8e3",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<br>size=%{marker.size}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","size":[0.00026349381611090824,0.04619648783300529,0.025657737127212685,0.022067474947553352,0.0017471542434110484,0.02208949418536525,0.008576166071003293,0.0016992262974795582,0.07449273076271853,2.2174473948679207e-06,0.018138902328717486,0.010272610695339033,0.0004287049371052972,0.012591919633839271,0.0,1.0188397205937344e-13,0.05537724091661655,0.0009674827449138016,0.03770102224380356,0.0001350926592886532,0.006136102129294642,1.3707534906915401e-17,0.0,0.0035006858143474453,2.4515384949389383e-05,2.0548910900185522e-09,0.0033214689513534562,0.013490162918809605,0.014184254327872388,0.052074568263589215,2.9233872526566264e-11,0.03619510259377023,1.1897515420226049e-05,9.257637412840129e-08,1.6283357613927022e-06,0.022072916525094688,0.002591266307610203,0.0005989060825818013,0.0711665075179058,0.006069040955066609,1.7353380227552577e-16,2.1657857466312142e-12,7.871901995126858e-13,0.0,0.0008047673735066248,0.0007001999354041134,0.001448861416534732,8.036171716764291e-07,2.3560119155975967e-06,0.0478681915053252,0.02582639424633485,3.5117349954174225e-19,1.4994006336321334e-05,9.39706352708861e-12,3.7101082529955386e-05,3.4607178742741682e-12,5.985842295723756e-08,0.0009179546559978721,0.018907979915775315,1.922742929710082e-06,1.1455404019749904e-07,3.745345469637159e-06,0.008623186048922534,6.960576888080794e-08,1.4540945010053575e-08,0.048119902319716086,0.0458226100167078,0.0002481591886844623,6.596519042353379e-10,0.0051798310808206325,5.722198829870792e-17,0.040312722074605165,5.740262703888974e-07,0.016467323001517493,4.666066570477712e-05,0.0,0.061424834350869276,0.0,7.915223372778716e-05,0.0041095190811788005,2.422804123975435e-07,3.870309743833465e-05,2.4208923322529877e-06,0.003068401552198542,5.992361523687198e-06,3.2384031377489697e-10,0.0,0.0,0.006373632678902606,4.37436234611189e-05,0.025406140847272475,0.0013940498144133515,4.3721874313421694e-14,0.0002603520577204704,2.417953027535809e-15,0.005727191062788162,0.055296085140459444,0.00520555212475052,0.00036213262781833045,1.0771611185236578e-06],"sizemode":"area","sizeref":0.00018623182690679635,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[-1.295330530170944,-3.3096375130078983,-1.0529778686143443,-0.28063150788390523,-0.06482029688092084,-2.2688807814529683,-2.241818653964157,1.8901907517861656,-1.7412947918703394,4.408723714075675,0.022151379415041028,-3.3319752791856043,1.177907134157321,-4.5962111811723885,-0.4290005619025067,7.3554398178626625,-2.9795334123790176,-2.43969340134811,-2.9595186980947985,0.9598183843773289,-4.285656055722227,8.141719829641191,-0.96326444683524,-5.277982486628048,-4.410282485587525,2.023291714622601,-0.6275498970468649,0.6377819229663291,0.2579434999157451,-3.220822272835615,5.174159245430813,-3.3770397773450758,-2.747862751145788,2.0636541767520273,1.357324243556649,-0.5442288379477611,-5.375953605800025,1.9415730229043247,-1.5001705368055198,-2.2912230475306767,6.531369171847478,-0.9073089445500604,5.9825876565658715,4.184133120582951,0.5774737008414497,1.70393509591355,-0.6878702791517688,1.7579884347334047,-5.710271639495682,-2.153867799619847,-3.9151570024074323,7.703964183369286,3.506683365839674,4.716761308287995,0.9802147459516773,-4.746467506363366,-2.6986021617640943,-3.2872477466397894,0.29723108416723665,-6.677161642236705,-1.06 ...
# Predicted Coords: -4.374237887994306, -5.373016048005864
# <div>                            <div id="e2b62df9-1c0a-4fdd-a043-2211366ace2f" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e2b62df9-1c0a-4fdd-a043-2211366ace2f")) {                    Plotly.newPlot(                        "e2b62df9-1c0a-4fdd-a043-2211366ace2f",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<br>size=%{marker.size}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","size":[3.691709332301605e-09,0.013688504187089603,0.015838102365111326,0.017368179555668797,0.005999049279131285,0.021227494444893715,0.010839979502038648,0.004973746078817506,0.017851312487113438,0.0007122518761190365,0.02209828801704607,0.02000918150892493,0.0430526030272485,0.0005621742595188267,0.011122372397508141,0.0008729592100808571,3.064004333268096e-06,0.0003243857632236578,3.2940200950222865e-05,0.0005918296170749723,1.0751294800586323e-05,5.344308054420554e-07,0.01120275473013733,2.2767091407003474e-05,2.3596714583152995e-07,4.954372966445151e-07,0.0006008561075992693,0.007871826426793118,5.732198946758564e-07,0.024572036095143895,0.0011400809445678169,0.0002774820735730889,2.9624099086892587e-15,0.0008839886707497797,0.000499780915954505,0.003753595489428438,0.008547644027392646,0.04166137580017357,0.004177696081235032,6.159747774623643e-08,0.02881497335258902,1.6836106245157438e-06,0.0007786705363946537,0.00047069074840927076,0.0067362063956809114,0.010610534146368531,0.03275432995347608,0.022615835162630608,0.0015990714995115605,0.000373394591196348,0.051107070583795565,0.026533669164807375,0.03401418518332956,0.0013914950121207625,0.03722464589253453,0.009664223188264638,0.0026072943137985844,0.0010785085517695434,0.0011023603221492297,1.0482385433727804e-06,0.03193954099246695,7.2370164500142205e-06,0.007745756637508159,0.03142095997469622,6.152807262208426e-05,0.0007092947799770135,0.002658881359843781,0.026827010045389475,0.00019496192562505925,0.0015292850602380537,8.337074952893086e-06,0.0011305403113772657,3.3763991848089983e-14,0.03514385249236863,0.0001898720026269594,0.0013810591751819154,0.03895066071486594,0.0,0.001072188639061034,9.86546102877352e-05,0.0033961364774680847,0.01429813896915298,0.009004991198744632,0.00765784437372935,0.053305089524450115,0.0005905497861312502,0.006878954604793572,9.63326212226044e-06,0.0,0.00013229114776071963,0.022347552485862582,2.1095347303374086e-05,2.8155902659849853e-06,0.00020787834640544905,2.440562423922522e-05,0.02754482782223055,3.484993122190494e-06,0.034554541945356454,0.0001165207812386326,0.05696077851087342],"sizemode":"area","sizeref":0.00014240194627718354,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[1.6115215446485662,-6.240962906198789,-4.089817661719555,-5.2817554089756165,-2.2680854180674683,-5.927667183960885,-5.747927634384231,-6.648342848372297,-5.714260697627635,-7.355123881270359,-2.9421472014927064,-3.2417530047755614,-4.475546735670515,-6.241076116535995,-6.197368509694073,-2.521134546957834,-8.382269337516414,-2.445559680191718,-2.645268946810831,-4.211368960500022,-2.992922247499407,-1.5639590207742744,-6.138416882324116,-4.660576894850466,-9.488449473749291,-9.622373835099125,-4.107689559410318,-6.28297335405901,-9.553157563692594,-5.792967495700015,-4.830524482172731,-4.903022352779825,0.4829313238837662,-7.505175641317499,-6.521631370880128,-5.8513486467673355,-4.683314916845555,-4.3937674893011955,-3.9928161287595905,-8.770958658711109,-5.6865367409460115,-1.3831235066418752,-4.391386727851877,-7.757670788458339,-6.475792814375496,-6.32311612741873,-4.617849703906238,-5.865717844418874,-2.2428164754970474,-7.817195225234038,-4.077647547151523,-3.050003341319489,-3.324915354733611,-3.53413270811235,-4.82824607344075,-2.3398881839772767,-3.10007099395643 ...
# Predicted Coords: -5.610986828593038, -2.192517853251857
# <div>                            <div id="dd7e0596-1ea4-4a1b-8cf3-2757b7a8c2a7" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dd7e0596-1ea4-4a1b-8cf3-2757b7a8c2a7")) {                    Plotly.newPlot(                        "dd7e0596-1ea4-4a1b-8cf3-2757b7a8c2a7",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<br>size=%{marker.size}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","size":[1.5964815954428652e-05,0.0012546423692164218,0.0011681645123416801,8.436426168195044e-05,2.090884446579484e-09,5.4657793932718866e-05,1.5549728887481555e-06,0.0012387576483155467,0.00017359049504049292,0.0635518689868594,1.1902551214550977e-09,2.7228877825970195e-08,1.5225230099683467e-06,0.0842479436857394,0.0006742256429219976,0.0007223969352955946,0.02686854658307544,8.237278639550204e-06,0.0,0.0,9.671087102460083e-12,1.9131091462757896e-07,0.0009089895998118084,2.059384102496382e-05,3.500165923635772e-13,2.766233300875949e-11,0.00041177438718428393,1.0305203678846362e-05,1.4295918889424833e-10,0.021445532709593092,3.619986665692324e-10,0.05042813251025905,1.7965325577647477e-18,4.491756130765728e-08,6.6621467904147825e-06,0.0013709822264277088,0.1260093183169587,1.2158027697047905e-05,2.9937204193170977e-06,2.9856101409212205e-09,0.0012265423655644348,0.0,1.2582940053493757e-06,7.344954235149058e-05,0.0012421699842813903,0.00048207318964350247,0.008395116761436583,0.04044070574786876,8.460869240862462e-08,0.000782073923147341,0.0023834414113720476,0.08438555193924785,0.00048310837897266987,2.6672013943562032e-05,7.128576995003047e-05,0.040573637900644714,0.0003504996586864103,1.469654317255619e-06,3.775481060995129e-05,1.0750866184932005e-08,0.000774801327089631,0.0,0.04435565255390893,0.0002682036762832833,1.4992200796287293e-08,4.3043550976517186e-15,3.866087195718115e-11,3.3396282967517084e-05,9.260901883759583e-06,6.586019677782377e-08,0.03141278875745918,0.0028126658754511007,1.7382887128028107e-06,0.00011968583135099998,0.001256841556089482,0.0030329869309588245,2.3800547468069433e-05,4.3900677239022386e-05,0.03446454538428051,2.304396253671007e-08,0.005194144762064958,5.333664305463785e-08,0.06806791003492993,0.0013774654874856458,4.989806631674789e-08,5.495454228941264e-06,4.407131123701201e-09,0.07926355138250828,0.0,0.0,6.264551248782887e-10,0.0004131271995956843,0.14810192862422775,0.0,0.0,0.009937887397586416,6.735499515820298e-08,0.0007698347566969535,0.006606486030349562,5.625537615362316e-07],"sizemode":"area","sizeref":0.00037025482156056934,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[-5.772638764352094,-3.2312660123104,-3.8763403033015327,-4.742148778303655,-7.225255497277979,-8.775231137838299,-6.971274162003398,-8.085616456534439,-4.865170138436918,-5.347178160095161,-7.905867379482023,-3.8618843128378026,-7.491521453042848,-5.636630683651464,-7.768677871009401,-6.330586093894868,-5.4168993258590685,-9.147290775141576,-10.154236048744544,-10.006405768228936,-7.069714481586518,-4.930822365876394,-7.222746124470399,-6.722722511548731,-9.817529046999733,-8.864917834306071,-3.1496922036253,-7.582522402260814,-8.971907841127294,-6.457539808213806,-8.017929607289988,-5.806077393436145,-9.645401228367735,-2.6501847231883873,-2.2419149263539984,-4.15160071640242,-5.516118061219634,-9.053053868309068,-8.972012315572757,-9.561084587475092,-7.796818830942642,-12.462052442994688,-8.804881406924629,-7.966425220020776,-7.9068689275174195,-8.270143948543224,-6.117619414015633,-5.660434194268993,-4.373192923756714,-6.623368780292876,-5.250054411864941,-4.769323847014666,-7.9063372545523265,-3.036532925410752,-2.8712859456641784,-4.416013207844674,-4.079493949188174,-9.4322143941029,-4.838955841337207,-1.9194566928997716,-8.1061135 ...
#     Predicted X  Predicted Y  Step Detected  Heading
# 0      4.000000    -2.500000          False        0
# 1           NaN          NaN           True        0
# 2           NaN          NaN           True        0
# 3           NaN          NaN           True      -30
# 4           NaN          NaN           True      -30
# 5           NaN          NaN           True      -30
# 6           NaN          NaN          False      -30
# 7      0.612075    -3.761347           True      -45
# 8           NaN          NaN          False      -50
# 9           NaN          NaN           True      -60
# 10          NaN          NaN           True      -60
# 11          NaN          NaN           True      -50
# 12          NaN          NaN           True      -40
# 13          NaN          NaN           True      -30
# 14    -1.978008    -6.203273           True      -20
# 15          NaN          NaN          False        0
# 16          NaN          NaN           True        0
# 17          NaN          NaN           True        0
# 18          NaN          NaN           True       30
# 19          NaN          NaN           True       30
# 20          NaN          NaN           True       30
# 21    -4.374238    -5.373016          False       30
# 22          NaN          NaN           True       45
# 23          NaN          NaN          False       50
# 24          NaN          NaN           True       60
# 25          NaN          NaN           True       60
# 26          NaN          NaN           True       70
# 27          NaN          NaN           True       80
# 28    -5.610987    -2.192518           True       90
# 29          NaN          NaN           True      100
# 30          NaN          NaN           True      100
# 31          NaN          NaN           True      100

# %%
N, particles, weights, x, y, xRange, yRange, step_distance, angle_offset = reset(
    100, 3, -3, np.array([-10,10]), np.array([-10,10]), 0.5, 180)
#particles = create_uniform_particles(3.5, 4.5, -2, -3, N)
step_distance_std = 0.1
heading_std = 1
weights_std = 1
resample_std = 1
#Plot intial particles
fig = plot_particles(particles, weights, xRange, yRange)
fig.show()

Real_path_x = [3, -3, -3, 3, 3, -3, -3, 3, 3]
Real_path_y = [-3, -3, 0, 0, -3, -3, 0, 0, -3]
particle_filter_driver_code(N, particles, weights, completed_df, x, y, xRange, yRange, step_distance, angle_offset, step_distance_std, heading_std, weights_std, resample_std)
# Out:
# <div>                            <div id="2163b9a7-62d0-4530-b1c3-0b2d6858ac35" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2163b9a7-62d0-4530-b1c3-0b2d6858ac35")) {                    Plotly.newPlot(                        "2163b9a7-62d0-4530-b1c3-0b2d6858ac35",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<br>size=%{marker.size}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","size":[0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01],"sizemode":"area","sizeref":2.5e-05,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[-8.131918718520332,5.192966327232039,7.050123954807248,1.715229641308074,0.5412722865572857,2.685912236324304,-0.09992314628627419,-3.4151613729137376,5.356087473215068,3.621583299679523,9.983497984275147,-3.848202240447323,4.597602142431768,-0.23645134672262635,-7.9993692937768675,-3.0623607779712376,6.341334550956713,2.416160408009823,6.071872691421856,-6.110343937057761,2.956185178190278,-7.47367301818473,9.18984563298962,5.4744993903709,0.8882061667584278,-5.923194960819678,-3.261559506439939,4.514394111779003,8.693453041572042,2.8043755705873696,-0.1694919403620645,9.16319128043044,-1.8757447445485447,-1.0278490904114594,4.424637595233275,-1.0301950349369413,-2.803001419010993,-4.935017491192943,-8.241166608024528,6.032417904773123,6.493470767297101,-5.8736565938021235,2.5021829166865235,3.260420351406861,2.0692402813798427,-2.329865621990315,-9.04434483869144,0.8060761533153311,-6.99184177481748,9.244312095059776,-9.514687470571662,-7.884666252021335,9.958433693514223,2.644444978555205,-7.81752854365344,-9.887393853142882,6.249075513161483,0.40648595724181114,7.976491824107388,-7.534987105831101,-0.31103339027008303,2.183162750197159,-8.815222794224516,9.619441184815422,6.334475320646032,-6.965992253292574,2.610665983210886,7.813138100279517,8.516712289780742,-1.5489442644482168,0.9316550082631014,1.849906629400417,-7.931343050594755,-0.2420961193773845,-3.2867847205562732,-4.360973352174153,-2.4675881892610967,-5.912870174203118,9.643689995934338,-4.95437313754004,4.404207271072627,-5.444027509407093,-2.1462885305620905,7.413604359061939,-6.981195702351721,2.829610253167715,-2.7219678026148024,6.07558419570185,-5.326447377416709,-7.899430290376279,-6.292669853528232,-2.162260648265457,-1.6466013829166748,9.067816508537447,-6.417929455433593,4.132051405499585,0.7638095190300564,1.5181992151852235,-3.9260847434665074,2.5408310559493525],"xaxis":"x","y":[8.16586872700077,-3.2481010294615835,9.487900789378376,-4.844072087719045,-7.55135617439755,-8.752992044563985,5.384184512824389,7.696921540971463,-3.4610819444230785,-5.796124270484597,-7.073723501840174,-2.7356131340864698,-4.975176050453762,-3.1877191654923864,-6.52900948821406,-6.78996015695994,8.110147901691128,-1.349884653720025,0.23841954146030453,4.61492520103263,-9.626092463257287,7.894061073755722,0.5796275692490696,5.61480451503046,-6.164873263910087,-7.04711169374078,3.125205467728012,-6.764177752232559,-1.1910513759395531,0.7428790257433686,-7.4950179981106295,5.415614666323643,4.143724686687346,7.367715532056437,8.240646149793967,-8.751002888472897,3.192126667272772,3.6183949033802136,1.465727625154269,-7.122233296998168,-2.1170228368583555,-9.91273255624213,9.27292858192197,-5.87826085823864,6.07468 ...
# Predicted Coords: 3.0, -1.6666666666666667
# <div>                            <div id="ee6153d9-c6d9-47ff-8f9d-e13076969652" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee6153d9-c6d9-47ff-8f9d-e13076969652")) {                    Plotly.newPlot(                        "ee6153d9-c6d9-47ff-8f9d-e13076969652",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<br>size=%{marker.size}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","size":[0.00767808035850572,0.00012692294353560201,0.010985732127791463,0.0005578664364344199,0.018873577967274725,0.002159019999454783,0.010241180599826268,0.015137565291593035,0.0005230277393178746,0.029736506092417767,0.005965740535554909,0.00025103638670345626,0.032362821681051,0.01433270545865214,0.016065332926612202,0.028457915255143327,5.7747324348423995e-05,0.019807944793415695,0.0012295032258117689,0.0061386532761110515,0.0036007759830189124,0.02086792572463026,0.02593717111635046,0.0016653109086305384,3.051181723536968e-05,0.002118189364389157,0.01039276802439164,0.004777404794751702,0.0002800700711050888,0.002084145493091573,0.008604647442667633,4.0566632873455184e-05,0.020604846735118063,0.0004079395353684098,0.012337687905989485,0.0217555509328887,0.0019722877598287317,0.017752860140591114,0.0025649140266943813,0.00688880620068545,0.009282453852316184,0.0023423812802843245,0.024275039526132258,4.598348154488227e-05,0.01854588725674523,0.0047382467159626795,0.007895830023322203,0.0018345649221487806,0.0022046679338107757,0.008655388813788105,0.005640406171693079,0.00011962388281352738,0.019550745142105568,0.017876549474957086,0.007863250830297508,0.004598777637365605,0.015836007656975026,0.000280199353623522,0.018091525066703303,0.0025695726382126607,0.014438799615212855,0.0010145897028614186,0.0059231172169436665,0.030021547723864894,0.0008364844523357316,0.007973049007019981,0.00967162537803796,0.02970626792659985,0.0005215238816403337,0.005480353863250556,0.014508294674424941,0.024326698208323505,0.02169235426032517,0.007967856554577584,0.02458454431281865,0.02380828537738279,0.0004209592238687282,0.021672759382059193,0.0029961890039224576,0.006797443225317955,0.0025759089570817958,0.01745645215929437,0.014547346692161171,1.827992472744588e-06,0.0022485118873177964,0.0136277338997785,0.0045469036443025026,0.014324799076318064,0.01847944943080631,0.001735427462352578,0.02838083514880823,0.001295123785967393,0.0010017037153975288,0.01308237004370755,0.02389428573772088,0.0016446835292344539,0.012154493447416197,0.016172480809356262,0.0006744012336787966,0.0001721556653803575],"sizemode":"area","sizeref":8.09070542026275e-05,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[1.5280617506575884,-0.29916739958826444,1.906757107761564,0.4308045595089043,1.9505395630125848,1.0938342548022992,1.484713589899116,1.917556665344219,0.48894375444008675,2.5517521710851887,1.1600906926351287,-0.1049465840222008,3.0820220964738665,1.7138967141618173,1.9027951998972066,3.50576444087391,6.524213406358724,2.148097877507963,1.75275556869058,1.2887289005864808,1.2193072131995668,2.2784862574971596,2.424800258822088,1.770967602788315,0.23488481144918216,0.8042191161237287,1.5858187312052778,1.1388489377347182,0.04136231354186881,2.5031761564744857,1.415483326279864,2.8586921810934878,2.252221802753466,0.23940188693222253,4.224199879135787,2.7538242103615493,1.1028052621396087,2.8670537616492737,0.9678052290475441,1.2357250492718492,3.1340186069473988,0.7044477060097363,2.5813668082983727,5.348078557166428,3.4903297343171307,2.610610880866061,2.5281222927416613,0.5994751760768957,5.086269897590866,1.5673061141005777,1.7695808181275487,2.7993273235769776,2.4886052521802484,2.726640025426509,3.0861282851422147,1.2551673094301412,1.8809396464664838,3.526683595998 ...
# Predicted Coords: 2.0, -1.6666666666666667
# <div>                            <div id="e94f4390-8a43-409d-b1a6-79e96623c4bd" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e94f4390-8a43-409d-b1a6-79e96623c4bd")) {                    Plotly.newPlot(                        "e94f4390-8a43-409d-b1a6-79e96623c4bd",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<br>size=%{marker.size}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","size":[0.0009863513610599585,0.004207136595790808,6.030217962238958e-05,0.004480596932950143,0.027007522444703027,0.021809384920350613,0.008653924628572446,0.001132372025626018,4.850901968085046e-07,4.524736769839565e-05,0.0001363079908965756,0.020199242559843095,0.03683107659825506,0.00010949710297205394,0.0011888392399398637,0.006488591291217535,0.0003236835707910325,0.0017715960621426594,0.010341364741019711,0.004488521351886653,0.022230315952214676,0.002775129063351791,0.023112226449641515,0.002868934438401904,0.036647219995629,0.016718910327706928,0.008485813231096824,0.00013343918718985772,0.001700227945243079,0.036465665698424084,2.5619416119253304e-06,2.913050496755618e-05,0.002621978009073916,0.028788165566314625,0.032425091180100986,0.0003854823113644279,0.03596266931470217,0.029450472608625166,0.03298938228866184,0.00107408196795327,0.016506265398833393,1.3975411923143167e-05,0.005261224760539942,0.025015554439483927,0.010307632166187991,0.001894654914919352,0.0007166312973090035,0.003759426959103188,0.02555153926897801,0.013168383432469078,0.0045744704089948855,0.002645512833249515,2.819701202036199e-06,0.018459785509836103,4.516359642165729e-05,0.0003215714126708849,0.012411663489568557,0.010227556906994761,6.965581684205249e-05,0.013233302047051011,2.7071774879954617e-05,3.2193492926635715e-05,0.012374196403847942,0.03540124662783281,0.0342830219866582,0.01780485578196037,0.0018810370726476877,0.012311229241970733,0.0013128926112497,0.005710301272293714,1.4559815722954574e-06,0.006224531292460888,0.0006777303503883363,0.021216281875868014,0.019630523595327472,0.012221128392362677,0.01474128506154222,0.011942467244886047,0.004072669485376635,0.002717995638938434,0.004563649545984104,0.0034804127286664896,2.0815875995618633e-05,0.016999239140036693,0.03405258588179934,0.02343273735914765,0.005145686715728281,6.0174145238133223e-05,0.0008991847431289233,0.0002433030915982975,0.006503254908512692,0.005319180946507825,0.0039211410267418695,0.01224744271789063,0.018748030186094177,0.004094772781232773,5.179166158720402e-06,0.0009269356972864807,0.014800336638013436,0.0006360897088583174],"sizemode":"area","sizeref":9.207769149563765e-05,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[0.3541712468075764,0.6158260488607927,-0.3926316134041813,3.354111475287631,2.288705679608939,1.6731800421487466,1.944525177809256,0.14790169494682326,-0.6463035457277955,3.0995108201405746,2.7915509710648094,2.656346097305749,2.1282357458052994,1.7033903179747598,3.8469704774059394,3.221097030438792,-0.03505568327170083,1.0072151437995212,2.1009828067306366,0.7800422640129652,2.489749879837908,3.3988596395848623,2.2276402285183288,1.6027528552594192,1.7802865508103525,2.9058420174048853,3.022243758811408,-0.2705691994827555,3.7471732064701837,2.1173057785049276,0.10397866504966946,0.609729554688929,3.516657116882937,2.530670913579843,1.7348232385691302,4.030339164539978,2.2641742479743248,1.534402977831948,2.3320543668265334,0.2842108919964301,1.1114381832347662,-0.48627150598124336,0.8789546381578086,2.407157810450263,2.7016186512822937,2.2387165812076173,1.3466661330943028,1.9509036983747945,2.6179928192483604,2.14670585168182,3.4429889661632584,2.8342536503882143,-0.620701215490626,1.1497554217676655,0.22350274398549175,-0.101402431364783,2.4799283685222804 ...
# Predicted Coords: 2.0, -1.6666666666666667
# <div>                            <div id="df56e6c8-d29d-4642-8855-16b7c659d198" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("df56e6c8-d29d-4642-8855-16b7c659d198")) {                    Plotly.newPlot(                        "df56e6c8-d29d-4642-8855-16b7c659d198",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<br>size=%{marker.size}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","size":[0.0013483748329996437,0.003123234415679397,0.0001208888298922967,0.015813043980404787,9.186661531695623e-10,1.615006001447141e-10,0.011297676854743866,3.6743367278697195e-06,0.008577758899064022,0.0003251115964273418,2.672487020502741e-11,0.004821157206175424,0.0001889175851295514,0.07958716119192084,0.019731558961611516,2.209576522604322e-06,2.5757431524143188e-05,0.0007985429424809348,0.0009614488896815595,0.008191204440799309,1.2215127400483096e-05,0.007801862654507103,0.00015041932886588125,1.3765216056098872e-13,0.0075177697154095845,0.05334767895359247,1.3304990620082146e-05,2.7727207546025224e-10,6.149144095759261e-07,2.1597378900465887e-05,1.1237368655165626e-08,8.014027383821747e-06,6.852102375411197e-06,8.621553683796396e-10,1.1453848874858496e-06,0.00034169493307197496,0.004290095985748304,2.7549490850623252e-14,0.005693553960753904,1.2237297654312737e-07,0.0027989447719211826,0.00018136964158756285,0.001066399723952458,9.551360039840397e-06,0.08511813852878572,3.372296759637065e-07,9.86501593433366e-08,0.012823730953229213,4.863672247618439e-05,3.547001673447753e-07,0.02849141334437958,3.2267914639117453e-07,0.013088261951511776,0.0072880469383262755,0.0336479061207381,7.316792662184497e-05,0.010342222350840554,0.04258187454248894,1.708637633062052e-05,4.091494505003751e-09,2.9148636708150494e-05,0.005589060818201847,0.010521300898889415,1.4057412002915867e-10,0.001965253809276372,9.438576298549436e-07,1.4083234209869906e-05,0.05765291810224908,0.00020726321318359942,0.0011194526824868682,0.009059260464317837,0.0001755885777919028,0.011908188026443384,0.07469313519671779,8.251377557192722e-06,4.435877939552045e-08,0.010296090864018234,0.00020067952696676002,2.9548946556179993e-13,5.6778356208938115e-09,9.560065329040778e-05,0.054792244880476924,0.020242593492710622,0.08423930092211866,0.010166029892247628,0.004392295207526356,1.0447178470057666e-06,0.0014732907060306998,5.4685354520834375e-06,0.00012774720832479957,0.010002711653579608,0.05757417776286714,0.00011144660715953622,4.186380587148097e-07,0.057346004057853874,0.009680502248444543,0.006290840417780209,1.1508712514561437e-07,0.005988040188394008,0.022326911768164617],"sizemode":"area","sizeref":0.0002127953463219643,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[0.8693876653801058,2.54557773866694,2.181938266811922,2.712746553966091,0.45252369055877506,4.2096899912086,2.6475298267017084,3.258048936245286,2.8354544396276284,2.9906274891530034,4.0348307181923975,2.0123746248670265,3.377681175765594,1.986523218569421,1.4949835136034806,0.18063173964527612,0.485766082769435,1.2886878834887647,0.8188865836852282,1.6241906740810275,1.0725055983651282,2.7982122183023934,3.42054564078144,-0.18107056798658494,1.8320538205285901,2.3312763403008745,3.5973600052298558,4.478610148557879,3.8305239354160285,1.6321411648727406,1.3513009561240956,1.9425222783715452,3.6431470880602683,0.269002558127994,0.7572287805643736,0.8641071954112146,1.0839532102261726,-0.6568042528988147,2.364023870878561,0.05341609143620962,1.199016500229939,3.28949884626316,0.8155444017900867,3.5544722411963168,1.9258426825599357,3.3902704522462743,0.026054294532611655,2.4363266202976646,3.2350882221008987,0.1310143036360476,1.872163212249039,3.993448004587287,1.5266722595634468,1.170449038319747,1.4797557191582 ...
# Predicted Coords: 1.0, -2.3333333333333335
# <div>                            <div id="c316a1d5-1ac2-4699-92ab-1e1ab60f0cbe" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c316a1d5-1ac2-4699-92ab-1e1ab60f0cbe")) {                    Plotly.newPlot(                        "c316a1d5-1ac2-4699-92ab-1e1ab60f0cbe",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<br>size=%{marker.size}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","size":[2.7158973298303527e-192,3.995637897193452e-101,1.1927701481405449e-231,1.0426950274838733e-24,1.8646865513432218e-17,5.33732867420926e-133,2.3145368709692423e-233,1.235980277941158e-40,4.579814040396451e-203,2.0451891035844395e-87,2.942019411171917e-121,0.9994521600535092,3.887026551808749e-56,3.768696872442753e-132,4.113520470845262e-68,1.5044313714193997e-271,2.0019770801885134e-57,6.5961370271484564e-130,7.047720488232996e-174,1.929075728393447e-127,9.727720025539185e-108,7.753689e-317,1.0545971892987234e-31,1.4406904908508927e-106,1.5186087162422555e-23,2.073601382825867e-91,9.685478969637822e-115,8.81595646062784e-79,1.742815187691483e-161,3.031496529870441e-250,3.6405282716319328e-152,5.106340468041199e-59,6.79728138288955e-45,3.303502683459938e-105,0.00017981292249417865,2.642930645280946e-53,2.418353460458909e-146,4.790966204270638e-76,2.7307732530203108e-15,0.00030786608838581365,3.577311527768322e-41,2.373284442670748e-207,3.796022844750742e-94,3.0911838071441343e-46,4.641294803776507e-56,5.862731131755114e-05,3.4170215918268345e-63,2.9312691027158943e-106,9.416283772144055e-128,1.3677923683463055e-96,7.711988751346428e-33,3.4081095651848518e-183,0.0,1.0058110164705555e-130,2.3035100976941305e-131,8.689131796203635e-73,1.2844989049171775e-64,1.1103589617465985e-18,8.746109870982058e-195,8.729961909962264e-164,2.9957839088398345e-81,7.047292907739404e-263,1.1116183149024396e-64,1.4186063730310169e-72,3.413131759761918e-75,3.777612517481384e-21,2.4490321490120124e-109,3.4696297623224582e-220,6.344695144412226e-07,8.974250570971873e-127,6.323301829753843e-26,1.0591045364980826e-31,2.43513268457227e-234,3.616217163967948e-40,5.889559057760902e-121,1.0945630258436983e-18,1.5878099827090625e-137,6.451251558967814e-186,5.592747773803343e-32,6.9121818847797845e-161,2.3390451682517282e-130,5.557083563721404e-07,1.282302840268029e-54,1.4787460527051403e-60,2.738176709408524e-169,1.0608003738925103e-17,2.476004152646888e-19,3.434463815754947e-07,9.87214203334172e-15,1.6944236530292104e-30,2.8260054270063098e-14,1.1218210258986977e-137,1.5386695798648093e-26,1.651800754375032e-95,1.3759383505293284e-126,1.72005592101678e-166,1.7993453276038245e-66,3.470212984641387e-61,2.4930784305376593e-297,5.879703254024684e-47],"sizemode":"area","sizeref":0.0024986304001337733,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[2.3087093468085698,1.399051678068878,3.9251352298943,0.6226716721645293,1.4961198748455335,2.721320350483972,1.7127778846652384,2.360983219529727,4.055891706397347,1.7768452738967777,0.4877611057212372,0.7911291092772859,2.4643348240981426,2.2269295450381934,0.49868174637806084,3.790143956389298,0.4731115056045272,2.032007484539344,2.732587002350242,2.3340895810010527,2.9926030516934965,3.587520000064586,-0.011471498494004084,2.3324288883344773,2.0301149480477303,1.7021051305655766,2.0374887868970237,1.4169970299182597,2.110284658256997,2.5394236426595453,2.218728842367655,0.26857122064140104,1.393633372761974,2.232684474737761,1.1107961900525152,2.2223405575666124,3.5584215313447167,-0.09045799935910592,0.16745400599160942,0.7501035415693502,2.3775898346226167,3.678639815732128,1.0742059368397203,2.163219504265003,1.4653610083329778,1.3450864517872803,2.101123100857002,2.949137188539472,0.8050511672014335,2.6330586527723128,0.679688929 ...
# Predicted Coords: 1.0, -2.3333333333333335
# <div>                            <div id="71d31356-4d67-4ed1-9f26-fb98d6c1b894" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("71d31356-4d67-4ed1-9f26-fb98d6c1b894")) {                    Plotly.newPlot(                        "71d31356-4d67-4ed1-9f26-fb98d6c1b894",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<br>size=%{marker.size}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","size":[9.63668572271904e-152,4.298355642342263e-165,1.3758516720916032e-26,2.682439765038841e-07,3.313595261672845e-56,1.800565990591126e-38,4.2074958053012864e-32,6.074475058523741e-25,2.429613886080429e-75,2.0292734236717896e-37,7.410899067892656e-56,4.8588230742054736e-80,1.1829321336441013e-39,1.828421885733246e-95,5.606905747641976e-71,2.8803920704685117e-78,1.70468900030375e-124,6.702674108000408e-89,2.8855842813190216e-52,3.946584983907117e-12,1.5552037517923685e-205,6.88391183504474e-173,8.677412277832646e-149,2.0691364410810768e-48,1.4140513440893036e-17,0.0006486698465066872,1.0455304351456702e-223,1.731164439985962e-51,5.340656975499947e-53,2.3916494952649407e-59,0.00010990446073219275,3.980410265288735e-105,1.2809202667966384e-05,2.7130616843687143e-64,0.002989749205246131,8.828256427907608e-89,1.189036170859938e-10,5.132056735046715e-35,2.384575626961533e-115,5.811916898909327e-28,3.8626406443250833e-197,7.341778034014754e-18,5.7297681878423564e-46,3.447902519867032e-59,3.0108747549280674e-149,3.748379224730034e-19,1.0852536677310132e-39,2.383712519004849e-19,4.917593873398617e-09,6.520716781288378e-52,1.4241018835501013e-34,5.68853133572482e-125,5.17925179253779e-108,1.453721708593639e-74,1.7240126334019495e-104,2.0665514201477015e-39,5.974245923221171e-33,2.8538962195545378e-70,2.7471776138281313e-49,1.4422642602585133e-55,0.00920735198255101,1.29267308003578e-67,3.855936272139049e-22,9.054246176229197e-06,4.23468887101349e-26,4.3866237886946204e-07,2.774741660060319e-28,1.1354582425303308e-23,1.0213834021184962e-32,0.0012036452982506496,0.38258012311360634,8.366203257229883e-71,1.466311832165411e-51,3.788752924136832e-164,3.401375265201991e-44,0.49296893846819717,9.354273659245323e-23,1.9463572851952062e-08,1.1188390278550913e-54,1.1360331965855048e-65,5.479401240766226e-171,1.5671704658200582e-09,1.76721101508991e-07,5.424634157813431e-20,2.016891450424351e-140,8.851608590583372e-75,7.859192741667208e-73,2.375736409402385e-159,9.984799163663965e-124,3.9455128085518194e-28,2.0693336798846736e-55,9.812014698053407e-111,0.1102688443661056,8.777355163473298e-32,1.3926809387862402e-33,4.733474499963972e-131,2.7508179020068845e-41,2.447809204592022e-42,1.1131559025966219e-10,2.5934721983174667e-40],"sizemode":"area","sizeref":0.0012324223461704928,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[0.4221189569718582,-1.7534853477890786,-0.1054952717577875,0.45810438365109546,0.1419947117857111,-0.304737465202916,1.746500312738918,0.08220216724379781,2.3850187611009153,0.7293929641684707,1.3269855011255234,-0.3442452325884229,1.4676044456797852,2.397880846049267,2.7983877888873017,1.3849881993966544,1.6197420920815109,1.238893095036928,0.8841525575288515,0.26007111039365705,-2.0728598825616453,-0.1766978954068723,-1.58648959193151,2.345722389054128,0.18795294145801167,1.408581485277939,2.694213880394371,2.364250488585721,-0.23234620773533288,-0.6085866882104074,1.4596819795177998,0.4718518640287108,1.4832877706050176,0.26087333318329764,1.3808851199540872,1.5231113404859835,1.4439509261149346,0.20439726860059781,-0.3719641414254995,0.828575232180855,-0.7847822773968496,1.2893228816679607,-0.3000134443103344,-0.347335745335428,-1.6138052659831101,1.9299345191692763,-0.07471977311687106,0.11461996445568068,0.5406684340056911,-0.378217927105733 ...
# Predicted Coords: -0.6666666666666666, -2.6666666666666665
# <div>                            <div id="0db4505e-624d-4360-8e6e-3aad5d65d3ca" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0db4505e-624d-4360-8e6e-3aad5d65d3ca")) {                    Plotly.newPlot(                        "0db4505e-624d-4360-8e6e-3aad5d65d3ca",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<br>size=%{marker.size}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","size":[1.528305008007805e-20,0.0010402864755241056,0.0017840427165826795,0.00017912586187756642,2.8371641942605346e-37,1.670886806165915e-17,9.323950139367023e-39,6.587616676547877e-10,2.076337210181943e-39,5.1996776784527965e-76,2.072200624740883e-87,2.638975189613866e-82,4.2566747310576364e-35,7.684280791694919e-16,3.5622087289404824e-150,6.559143879144223e-36,1.1362162856532925e-38,5.576367884880736e-26,6.356717705547015e-81,2.676630307380489e-22,2.696654671574323e-09,1.1607944054795e-06,8.883796250050595e-117,2.1399849491677333e-41,2.1529243529478227e-81,2.3707644874147425e-99,9.299989040969556e-28,2.1361718972019894e-61,5.930930451467403e-35,1.2906014887723248e-12,7.561309156091821e-05,2.4489712650694176e-28,1.542900313939544e-49,2.035863348777529e-229,5.128271961319954e-10,7.195266567059004e-77,1.283038809587663e-44,0.0039360584978846164,7.04122142297477e-05,1.7363692836444116e-19,1.3983880010068247e-05,1.849702375454288e-24,1.2602895338080201e-49,9.892639310922038e-30,0.3653804157541366,4.388942521173097e-195,2.874450463350428e-14,2.222697604232708e-56,1.4938849871918945e-06,9.78395191835236e-74,1.7634686371892032e-35,1.0653084986608573e-06,0.00608811058756972,1.245627712085797e-49,1.119862120367119e-26,8.562803607241271e-14,7.748600450519221e-74,0.5161054133361812,4.141621168063261e-17,0.0002850560251773583,3.7845067066678065e-32,1.653917250024741e-05,0.0007774306444649614,2.1442303326055388e-31,6.466426286985716e-94,3.064480921875286e-55,1.0355407838860172e-19,8.940065306728669e-42,2.1724922129446177e-43,4.307120644743183e-24,8.854589708696595e-10,8.278045732909267e-19,0.00011447290210650927,6.391201580569595e-95,1.6491805842369959e-80,5.549049586539205e-41,4.3097316760505677e-63,1.7431271970183895e-57,3.295556663581429e-21,0.10380247616238139,9.444893005044832e-09,6.869251767848958e-60,9.202676894421665e-45,1.7405918504684725e-22,4.733005090783111e-154,0.000317625354387345,6.040121878977446e-43,3.8840779885880464e-73,6.728985584490143e-19,8.768036948657563e-11,7.075425994359362e-29,3.2725018866557316e-97,1.5171629754353125e-14,2.7442914580005983e-38,9.047286683595977e-112,3.822513881898034e-96,7.683512613971657e-14,8.831814589161072e-81,3.1420616618855897e-145,9.203047760025337e-06],"sizemode":"area","sizeref":0.001290263533340453,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[-0.6524633743619053,-0.3110204168529444,-0.9983197555964768,-0.7726357117904079,0.090856139545339,-0.7435007184484653,-1.8153437764856148,-1.2989296908911228,-0.30356824571398633,-1.6356346160495052,-2.6495630607019267,0.2219015582581938,0.35545624307721824,-1.365047025036016,-2.7344305740256165,0.43187389658573794,-0.5140001971050924,-1.1214281247703322,0.5369667175893434,-0.6267499394262434,-0.4462157066208827,-1.175673628731257,-1.0985453030582164,0.5908326284436795,0.31253955988855164,-2.0815594280760115,-0.6757674282340923,1.0002065781946197,0.5407829784115791,-0.03714164821638033,-0.24744126382755027,-1.5243212239045845,0.8261443665703582,1.2628605153398786,-0.9062953735192663,-2.40295259485309,-1.680815608075981,-0.46786775866022057,-0.2639967090328906,-0.2725901078069136,-0.2690567295319508,-1.413677554278932,0.8058495371067981,0.44897195178620153,-0.7602865929488544,1.9913733323482128,-0.9063191455617614,-1.339759452117696,-0.6559055995546836,1.16449050701 ...
# Predicted Coords: -0.6666666666666666, -2.6666666666666665
# <div>                            <div id="aa50cda4-1f4f-44ed-bfba-75c7e2729ab1" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aa50cda4-1f4f-44ed-bfba-75c7e2729ab1")) {                    Plotly.newPlot(                        "aa50cda4-1f4f-44ed-bfba-75c7e2729ab1",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<br>size=%{marker.size}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","size":[7.603995019577587e-45,1.6207132818310686e-118,1.0954748544391004e-147,2.0222310719922446e-12,5.549174197382345e-46,6.8046901296522495e-183,3.030876168964337e-08,8.085593966261888e-307,1.5157204784159245e-50,8.953461089051574e-57,4.202816855675355e-71,2.1173352559250297e-42,6.20896481112755e-166,3.1780504144505882e-43,1.2589117016116163e-154,1.9361224895836266e-49,4.757716535962198e-62,1.3427062042712068e-63,2.3894545600495674e-204,0.029031142297688193,0.0,3.0168526518613404e-21,2.62721210236096e-70,4.3856887039689055e-61,8.237810055133452e-47,2.825180912687568e-10,8.4e-323,2.3036849396153676e-256,3.2011433075236246e-84,1.302833762148304e-55,3.379278140139714e-94,5.963788270303062e-25,4.3771440251953974e-222,1.455605468896148e-175,3.63578172349916e-11,1.0174249140308536e-36,2.6290169744677424e-25,5.68045043577346e-88,3.064109017659505e-63,4.528960406254255e-217,1.6546159030978223e-15,1.6355889455889776e-95,2.0315776311252895e-83,1.714646317923182e-244,7.665571964315498e-13,9.884922504549231e-27,1.8943513599743015e-224,2.179766477929416e-89,2.4514523932087433e-23,3.662229492235646e-87,9.398992059526623e-66,2.307057874246164e-192,7.366318852595092e-140,1.6297797449835842e-143,4.7817977390867537e-116,0.0002549332183468486,1.2889347226890069e-72,1.7191992907509048e-182,3.141142299427389e-79,3.5022741552595445e-82,1.7608335995854132e-59,7.291419033170971e-85,4.309928446596102e-68,0.006406449047147908,0.0,0.004569210370063817,6.281222826325143e-36,1.157561378347552e-32,0.0,1.4108616227743752e-136,2.3162914269834316e-08,1.4951248423910521e-71,1.730117641211943e-147,3.378149124223067e-103,1.0951837673299257e-90,1.4605566962285806e-120,1.2444576166984284e-31,0.0,3.7915992832591886e-138,3.3861016569229036e-60,1.4065504401702263e-152,2.3093584908170498e-40,3.59774645934216e-09,4.244661324266604e-06,8.872941440336545e-115,6.343241229565215e-134,3.049115266290129e-53,5.564465491724822e-22,0.9589360505368688,1.3414893829734561e-50,2.794020522135888e-19,2.4900387837231915e-150,2.627334698567004e-23,1.3276686015859067e-100,0.0007979124774714257,1.0808456235842393e-225,4.4071342790329005e-34,4.364032268594451e-212,4.313038109590954e-109,6.145191097660871e-197],"sizemode":"area","sizeref":0.002397340126342172,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[-1.0276903475463013,-0.7167986885131917,-2.235026761594435,-1.240377768386669,-1.9337680346972126,-2.1045742652505606,-1.2595039619732766,-0.7798197615469437,-0.7660654363005815,-1.9515979641762298,-1.0731460332193374,-0.12857701629537988,-2.5001279069132187,-2.0639473302467173,0.2221257869507034,-0.3277893203568163,-1.9170776822857858,-1.6185855298935654,-3.1154424313965525,-0.3917632731126677,-4.372507543367053,-1.3517684779801853,-1.2928728791522248,-1.5145419926051766,-0.49812070266173925,-1.0862994358113132,-3.7365643913606825,-3.203114554941969,-0.045624515045414205,-2.2351604908175617,-1.4000322064998936,-1.3485264083057902,-2.495227261400585,-1.810164431946991,-1.2331821461638088,-0.5155980495094639,0.19558456450161765,1.3324891303506416,-1.5950212199719649,-3.38383760356329,-0.005845711184180535,-1.458976846653799,-0.20027710421119838,-1.0316236383298725,-0.6685953182250114,-0.1961874579505336,-3.3063008444123643,-2.229887431799849,-1.1637111676741427,-1.343484145327361,-2.1230661457659026,-2.307660 ...

# %%
fig = go.Figure(data=go.Scatter(x=xCoords, y=yCoords, mode='lines+markers'))
fig.update_layout(width = 700, height = 500, xaxis_range=[-10,10], yaxis_range=[-10,10],  title = "Samples from prior")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ----> 1 fig = go.Figure(data=go.Scatter(x=xCoords, y=yCoords, mode='lines+markers'))
#       2 fig.update_layout(width = 700, height = 500, xaxis_range=[-10,10], yaxis_range=[-10,10],  title = "Samples from prior")
#       3 fig.show()
#
# NameError: name 'xCoords' is not defined

# %%
-60--60
